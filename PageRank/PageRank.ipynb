# %% [markdown]
# # PageRank Project
# ## Zach Chase

# %%
import csv
import numpy as np

# %% [markdown]
# Many real-world systems can be represented as graphs (networks). These systems range from the internet, transportation grids, social media, and more. The PageRank algorithm was developed by Larry Page and Sergey Brin at Stanford University in 1996 to rank notes in a graph by importance, and thus create a ranking system most famously used by Google to rank web pages in their search engine history. This project I will implement the PageRank algorithm and use it to rank the nodes of networks.

# %% [markdown]
# ## Background Before Implementation

# %% [markdown]
# An Adjacency Matrix (A) represents a directed graph which satisfies $A_{ij} = 1$ if node j links to node i and $A_{ij} = 0$ otherwise. The figure below shows the adjacency matrix for the image on the left.

# %% [markdown]
# ![Screen%20Shot%202021-12-18%20at%206.51.28%20PM.png](attachment:Screen%20Shot%202021-12-18%20at%206.51.28%20PM.png)

# %% [markdown]
# This model can be a potential model for a collection of webpages, where each may have a hyperlink to any other page. Note that each node represents a webpage and each edge represents a hyperlink. To prepare for a proper implementation of the PageRank algorithm, we must first avoid sinks by modifying each one so that the each sink has an edge added to every node in the graph. This means users on a page with no links can start over by selecting a random webpage. The example below demonstrates this situation.

# %% [markdown]
# ![Screen%20Shot%202021-12-18%20at%206.47.51%20PM.png](attachment:Screen%20Shot%202021-12-18%20at%206.47.51%20PM.png)

# %% [markdown]
# Now we will implement the algorithm, in the form of the class below.

# %% [markdown]
# ## Implement PageRank Algorithm

# %%
class DiGraph:
    """A class for representing directed graphs via their adjacency matrices.
    """

    def __init__(self, A, labels=None):
        """Modify A so that there are no sinks in the corresponding graph,
        then calculate Ahat. Save Ahat and the labels as attributes.

        Parameters:
            A ((n,n) ndarray): the adjacency matrix of a directed graph.
                A[i,j] is the weight of the edge from node j to node i.
            labels (list(str)): labels for the n nodes in the graph.
                If None, defaults to [0, 1, ..., n-1].
        """
        
        #Find size of A
        self.m, self.n = A.shape

        #Modify so there are no sinks
        for i in range(self.n):
            if np.count_nonzero(A[0:,i]) == 0:
                A[0:,i] = 1
                
        #Normalize
        A = A.astype(float)
        for i in range(self.n):
            A[0:,i] = A[0:,i]/np.sum(A[0:,i])
        
        #Assign A as an attribute
        self.ABar = A
        
        #Raise value error if labels is wrong size
        if labels is not None and len(labels) != self.n:
            raise ValueError("Labels have the wrong size")
        
        #If no labels assigned, assign them and store as an attribute
        if labels is None:
            labels = [i for i in range(self.n)]
        self.labels = labels
        
    def linsolve(self, epsilon=0.85):
        """Compute the PageRank vector using the linear system method.

        Parameters:
            epsilon (float): the damping factor, between 0 and 1.

        Returns:
            dict(str -> float): A dictionary mapping labels to PageRank values.
        """
    
        #Find A
        A = np.eye(self.n) - (epsilon*self.ABar)
        
        #Find b
        b = ((1-epsilon)/self.n) * np.ones(self.n) 
        
        #solve for p
        p = np.linalg.solve(A,b)
        
        #convert to dictionary
        PageRankDict = {self.labels[i]:p[i] for i in range(self.n)}
        
        return PageRankDict

    def eigensolve(self, epsilon=0.85):
        """Compute the PageRank vector using the eigenvalue method.
        Normalize the resulting eigenvector so its entries sum to 1.

        Parameters:
            epsilon (float): the damping factor, between 0 and 1.

        Return:
            dict(str -> float): A dictionary mapping labels to PageRank values.
        """
        
        #Calculate B
        B = (epsilon * self.ABar) + (((1 - epsilon)/self.n)*np.ones((self.n,self.n)))
        
        #Find eigenvalues and eigenvectors
        eigs = np.linalg.eig(B)
        
        #Determine eigenvalue associated with eigenvalue of 1
        p = eigs[1][:,0]
        
        #Determine the Page Rank vector and normalize
        PR_Vector = p/np.linalg.norm(p, ord=1)
        
        #Convert to dictionary using the labels
        PageRankDict = {self.labels[i]:PR_Vector[i] for i in range(self.n)}
        
        return(PageRankDict)

    def itersolve(self, epsilon=0.85, maxiter=100, tol=1e-12):
        """Compute the PageRank vector using the iterative method.

        Parameters:
            epsilon (float): the damping factor, between 0 and 1.
            maxiter (int): the maximum number of iterations to compute.
            tol (float): the convergence tolerance.

        Return:
            dict(str -> float): A dictionary mapping labels to PageRank values.
        """
        
        #Initialize p(0)
        p_0 = np.ones(self.n) * (1/self.n)
        
        #Iterate until maxiter is reached
        for i in range(maxiter):
            
            #Find p(t+1)
            p_1 = ((epsilon * self.ABar) @ p_0) + (((1-epsilon)/self.n)*np.ones(self.n))
            
            #Stop if difference is less than tol
            if np.linalg.norm((p_1-p_0), ord=1) < tol:
                break
            
            p_0 = p_1
        
        #convert to dictionary using the labels
        PageRankDict = {self.labels[i]:p_1[i] for i in range(self.n)}
        
        return(PageRankDict)

# %%
def get_ranks(d):
    """Construct a sorted list of labels based on the PageRank vector.

    Parameters:
        d (dict(str -> float)): a dictionary mapping labels to PageRank values.

    Returns:
        (list) the keys of d, sorted by PageRank value from greatest to least.
    """
    
    #Find keys and values and put into a list
    keys = list(d.keys())
    values = list(d.values())
    
    #Sort keys from greatest to smallest
    values.sort(reverse=True)
    
    #Find keys associated from greatest to smallest
    mylist = []
    for i in values:
        for j in keys:
            if d[j] == i and j not in mylist:
                mylist.append(j)
                break
    
    return mylist

# %% [markdown]
# ## Use PageRank Algorithm to Rank Websites

# %%
def rank_websites(filename="web_stanford.txt", epsilon=0.85):
    """Read the specified file and construct a graph where node j points to
    node i if webpage j has a hyperlink to webpage i. Use the DiGraph class
    and its itersolve() method to compute the PageRank values of the webpages,
    then rank them with get_ranks().

    Each line of the file has the format
        a/b/c/d/e/f...
    meaning the webpage with ID 'a' has hyperlinks to the webpages with IDs
    'b', 'c', 'd', and so on.

    Parameters:
        filename (str): the file to read from.
        epsilon (float): the damping factor, between 0 and 1.

    Returns:
        (list(str)): The ranked list of webpage IDs.
    """
    
    #Define list, set, and dictionary
    data = []
    labels = set()
    mydictionary = dict()
    
    #Open file
    with open(filename) as f:
        
        #Read in lines and split at /
        for line in f.readlines():
            line = line.strip().split('/')
            
            #Add to a list of lists
            data.append(line)
            for label in line:
                labels.add(label)
        labels = sorted(labels)
        
        #Update dictionary
        for i in range(len(labels)):
            mydictionary[labels[i]] = i
            
        #Initialize the Adjacency Matrix
        array = np.zeros((len(labels),len(labels)))
        
        #Complete the matrix
        for line in data:
            i = mydictionary[line[0]]
            for label in line[1:]:
                j = mydictionary[label]
                array[j][i] += 1
                
    #Run through get_ranks
    return get_ranks(DiGraph(array,labels).itersolve(epsilon=epsilon))

# %% [markdown]
# ### View Sample of Text File, then Rank Websites

# %%
with open("web_stanford.txt") as myfile:
    head = [next(myfile) for x in range(5)]
print(*head)
# Out:
# 
#  246911/32791/98286/98595/132956/209406
#  202286/32791/91478/91885/95803/98595
#  194898/32791/83942/98595
#  193160/32791/98595

# %%
rank_websites()
# Out:
# ['98595',
#  '32791',
#  '28392',
#  '77323',
#  '92715',
#  '26083',
#  '130094',
#  '99464',
#  '12846',
#  '106064',
#  '332',
#  '31328',
#  '86049',
#  '123900',
#  '74923',
#  '119538',
#  '90571',
#  '116900',
#  '139197',
#  '114623',
#  '15672',
#  '20283',
#  '108608',
#  '136623',
#  '6213',
#  '56800',
#  '62259',
#  '67827',
#  '64104',
#  '96254',
#  '82752',
#  '203109',
#  '178606',
#  '24083',
#  '217557',
#  '68912',
#  '41471',
#  '203100',
#  '19894',
#  '177473',
#  '203696',
#  '121480',
#  '268900',
#  '246911',
#  '146603',
#  '10984',
#  '84478',
#  '182230',
#  '210258',
#  '110923',
#  '147255',
#  '185201',
#  '102329',
#  '178003',
#  '188707',
#  '197440',
#  '208254',
#  '228036',
#  '247003',
#  '199855',
#  '230247',
#  '110520',
#  '112786',
#  '121418',
#  '101455',
#  '41677',
#  '66498',
#  '63712',
#  '84094',
#  '88621',
#  '35759',
#  '61413',
#  '17101',
#  '55398',
#  '32789',
#  '51075',
#  '21554',
#  '72982',
#  '104202',
#  '1662',
#  '94657',
#  '4889',
#  '48096',
#  '81525',
#  '11433',
#  '26918',
#  '79322',
#  '237162',
#  '132956',
#  '79383',
#  '264536',
#  '31597',
#  '76236',
#  '209406',
#  '215281',
#  '253851',
#  '6886',
#  '72430',
#  '181789',
#  '218365',
#  '71480',
#  '26441',
#  '78258',
#  '26121',
#  '260233',
#  '159242',
#  '64624',
#  '215608',
#  '39172',
#  '49887',
#  '114967',
#  '98286',
#  '274855',
#  '146068',
#  '151789',
#  '231532',
#  '56576',
#  '141161',
#  '44750',
#  '35966',
#  '206971',
#  '215951',
#  '28341',
#  '4594',
#  '227143',
#  '96419',
#  '1657',
#  '69983',
#  '203391',
#  '42621',
#  '268263',
#  '194966',
#  '271062',
#  '109337',
#  '147042',
#  '28022',
#  '56295',
#  '96269',
#  '135461',
#  '230921',
#  '86086',
#  '216147',
#  '207001',
#  '248137',
#  '31000',
#  '146219',
#  '278846',
#  '201055',
#  '51307',
#  '129150',
#  '209422',
#  '211702',
#  '36479',
#  '191683',
#  '37720',
#  '117677',
#  '271310',
#  '98794',
#  '167815',
#  '251336',
#  '44747',
#  '52857',
#  '223960',
#  '189206',
#  '252233',
#  '55418',
#  '228428',
#  '4278',
#  '223911',
#  '212468',
#  '79530',
#  '77280',
#  '196106',
#  '49995',
#  '65286',
#  '132166',
#  '202150',
#  '91411',
#  '207223',
#  '32027',
#  '36294',
#  '35873',
#  '41455',
#  '124601',
#  '75571',
#  '194898',
#  '227964',
#  '196143',
#  '218511',
#  '38847',
#  '120206',
#  '174717',
#  '72919',
#  '180131',
#  '74793',
#  '159964',
#  '219561',
#  '67327',
#  '116300',
#  '91478',
#  '166922',
#  '111171',
#  '247987',
#  '200158',
#  '18370',
#  '4854',
#  '51832',
#  '242950',
#  '267927',
#  '189138',
#  '191781',
#  '37430',
#  '165593',
#  '158597',
#  '176647',
#  '7365',
#  '74226',
#  '276426',
#  '127339',
#  '200207',
#  '56464',
#  '6564',
#  '162971',
#  '198699',
#  '269961',
#  '197549',
#  '241373',
#  '23581',
#  '34291',
#  '195370',
#  '229598',
#  '189661',
#  '130652',
#  '27696',
#  '245705',
#  '30304',
#  '9191',
#  '244703',
#  '72326',
#  '139275',
#  '503',
#  '223949',
#  '103752',
#  '107495',
#  '111452',
#  '122855',
#  '138117',
#  '196045',
#  '97109',
#  '44800',
#  '263142',
#  '154880',
#  '183324',
#  '185588',
#  '11442',
#  '17128',
#  '80902',
#  '84719',
#  '82511',
#  '110863',
#  '180406',
#  '183218',
#  '7002',
#  '203749',
#  '13787',
#  '2833',
#  '123381',
#  '23271',
#  '71255',
#  '55336',
#  '193160',
#  '268798',
#  '219178',
#  '117434',
#  '202286',
#  '68080',
#  '86876',
#  '34510',
#  '45738',
#  '112344',
#  '71998',
#  '214581',
#  '220946',
#  '225634',
#  '59571',
#  '141414',
#  '35933',
#  '249214',
#  '60057',
#  '92541',
#  '253533',
#  '110767',
#  '114504',
#  '219596',
#  '251807',
#  '53472',
#  '68915',
#  '195446',
#  '189628',
#  '12974',
#  '23125',
#  '172431',
#  '249302',
#  '250752',
#  '265935',
#  '241121',
#  '10544',
#  '115353',
#  '80717',
#  '50862',
#  '83942',
#  '72267',
#  '145764',
#  '183077',
#  '185325',
#  '19729',
#  '228856',
#  '257944',
#  '41275',
#  '47846',
#  '97282',
#  '123958',
#  '171197',
#  '47246',
#  '111873',
#  '109021',
#  '119872',
#  '5504',
#  '85382',
#  '67768',
#  '91885',
#  '95803',
#  '37548',
#  '91297',
#  '78671',
#  '265336',
#  '201490',
#  '30123',
#  '81585',
#  '143262',
#  '152377',
#  '73414',
#  '158486',
#  '61741',
#  '18325',
#  '23621',
#  '39036',
#  '232617',
#  '41516',
#  '47979',
#  '234071',
#  '60955',
#  '35880',
#  '41503',
#  '31238',
#  '29960',
#  '109820',
#  '281313',
#  '221972',
#  '229907',
#  '28707',
#  '66869',
#  '29509',
#  '108145',
#  '127675',
#  '30075',
#  '244442',
#  '238658',
#  '54364',
#  '37412',
#  '237932',
#  '8358',
#  '31334',
#  '206569',
#  '217507',
#  '226982',
#  '45377',
#  '72240',
#  '89587',
#  '129530',
#  '42713',
#  '235752',
#  '93239',
#  '56739',
#  '221833',
#  '4290',
#  '52954',
#  '79497',
#  '34551',
#  '233123',
#  '3550',
#  '215303',
#  '278260',
#  '270687',
#  '3936',
#  '47650',
#  '20951',
#  '244131',
#  '189051',
#  '29287',
#  '73118',
#  '15904',
#  '54895',
#  '70343',
#  '165472',
#  '167695',
#  '110881',
#  '132588',
#  '157431',
#  '161837',
#  '166677',
#  '172877',
#  '30327',
#  '73771',
#  '78455',
#  '243266',
#  '54674',
#  '143107',
#  '152449',
#  '162789',
#  '224073',
#  '167479',
#  '77733',
#  '99974',
#  '228055',
#  '126463',
#  '81070',
#  '84586',
#  '103483',
#  '75563',
#  '87847',
#  '92297',
#  '95362',
#  '97622',
#  '39093',
#  '196402',
#  '227864',
#  '61204',
#  '135283',
#  '224078',
#  '607',
#  '151941',
#  '194731',
#  '113322',
#  '115482',
#  '135270',
#  '229034',
#  '145798',
#  '198225',
#  '45914',
#  '261437',
#  '125597',
#  '101082',
#  '205178',
#  '55820',
#  '63280',
#  '1091',
#  '16490',
#  '94526',
#  '56145',
#  '60639',
#  '67231',
#  '115582',
#  '120737',
#  '125064',
#  '128900',
#  '210749',
#  '139155',
#  '32671',
#  '104910',
#  '201277',
#  '244577',
#  '3881',
#  '14218',
#  '126575',
#  '137464',
#  '144234',
#  '149208',
#  '151391',
#  '159444',
#  '164663',
#  '171307',
#  '174933',
#  '180151',
#  '183482',
#  '205269',
#  '210479',
#  '88791',
#  '56596',
#  '32781',
#  '75852',
#  '241478',
#  '88939',
#  '11362',
#  '17175',
#  '4815',
#  '114858',
#  '89799',
#  '93450',
#  '52060',
#  '90919',
#  '27848',
#  '101598',
#  '94841',
#  '143724',
#  '74543',
#  '83915',
#  '273142',
#  '39263',
#  '44564',
#  '50202',
#  '181444',
#  '279543',
#  '58089',
#  '69798',
#  '34626',
#  '3641',
#  '7314',
#  '53627',
#  '65498',
#  '69048',
#  '18268',
#  '250739',
#  '48314',
#  '90458',
#  '267205',
#  '278028',
#  '4365',
#  '217356',
#  '35503',
#  '50778',
#  '136009',
#  '23343',
#  '42637',
#  '34157',
#  '7916',
#  '6388',
#  '212110',
#  '130396',
#  '215902',
#  '10411',
#  '109056',
#  '279814',
#  '229957',
#  '77712',
#  '22494',
#  '79895',
#  '85692',
#  '109929',
#  '165271',
#  '270949',
#  '94366',
#  '202130',
#  '113901',
#  '245985',
#  '255874',
#  '171152',
#  '206259',
#  '3038',
#  '64773',
#  '108316',
#  '254588',
#  '74106',
#  '85203',
#  '92532',
#  '115569',
#  '125290',
#  '128685',
#  '135225',
#  '173606',
#  '194187',
#  '197989',
#  '228684',
#  '66144',
#  '89767',
#  '18712',
#  '19341',
#  '215053',
#  '218258',
#  '230629',
#  '240318',
#  '246001',
#  '34181',
#  '34889',
#  '37084',
#  '40349',
#  '52331',
#  '62410',
#  '67710',
#  '7027',
#  '9914',
#  '18233',
#  '33719',
#  '82517',
#  '87559',
#  '92027',
#  '95645',
#  '97931',
#  '20701',
#  '25644',
#  '42520',
#  '57749',
#  '189258',
#  '252373',
#  '14322',
#  '20101',
#  '2025',
#  '28504',
#  '32077',
#  '3304',
#  '36938',
#  '42125',
#  '44113',
#  '45726',
#  '47248',
#  '47971',
#  '49518',
#  '54000',
#  '64242',
#  '70719',
#  '75013',
#  '76321',
#  '78825',
#  '84768',
#  '86090',
#  '89299',
#  '92014',
#  '93979',
#  '95655',
#  '9790']

# %% [markdown]
# ## Use PageRank Algorithm to Rank NCAA Men's Basketball Teams

# %%
def rank_ncaa_teams(filename, epsilon=0.85):
    """Read the specified file and construct a graph where node j points to
    node i with weight w if team j was defeated by team i in w games. Use the
    DiGraph class and its itersolve() method to compute the PageRank values of
    the teams, then rank them with get_ranks().

    Each line of the file has the format
        A,B
    meaning team A defeated team B.

    Parameters:
        filename (str): the name of the data file to read.
        epsilon (float): the damping factor, between 0 and 1.

    Returns:
        (list(str)): The ranked list of team names.
    """
    #Open file and read in data
    with open(filename, 'r') as f:
        reader = csv.reader(f)
        headers = next(reader)
        data = list(reader)
        data = np.array(data)
    
    #find list of winners and losers
    winners = data[0:,0]
    losers = data[0:,1]
    
    
    #Note that the data collected includes the NCAA Tournament
    #Remove the 67 Tournament games to compare predication and actual tournament
    #winners = data[0:len(data)-67,0]
    #losers = data[0:len(data)-67,1]
    
    #Create the entire list of teams
    teams = []
    for x in winners:
        if x not in teams:
            teams.append(x)
    for y in losers:
        if y not in teams:
            teams.append(y)

    #Initialize the Adjacency Matrix
    A = np.zeros((len(teams),len(teams)))
    
    #Fill in the matrix
    counter = 0
    for i in losers:
        for _ in teams:
            if _ == i:
                lostTo = winners[counter]
                x = teams.index(i)
                y = teams.index(lostTo)
                A[y,x] += 1        
        counter += 1
    
    #Determine page rank from previous formula's
    tournament = DiGraph(A, labels = teams)
    bestTeams = get_ranks(tournament.itersolve(epsilon=epsilon))
    
    return bestTeams

# %% [markdown]
# ## Display Rank of NCAA Men's Baskeball Teams from 2010-2018

# %% [markdown]
# ### NCAA Men's 2010 Rank

# %%
rank_ncaa_teams("ncaa2010.csv")
# Out:
# ['UConn',
#  'Kentucky',
#  'Louisville',
#  'Notre Dame',
#  'Florida',
#  'BYU',
#  "St. John's (NY)",
#  'Kansas',
#  'VCU',
#  'Syracuse',
#  'Pitt',
#  'Ohio State',
#  'UNC',
#  'West Virginia',
#  'Butler',
#  'Duke',
#  'Texas',
#  'Marquette',
#  'San Diego State',
#  'Wisconsin',
#  'Purdue',
#  'Kansas State',
#  'Georgetown',
#  'Arizona',
#  'Tennessee',
#  'Vanderbilt',
#  'UCLA',
#  'Cincinnati',
#  'Old Dominion',
#  'Villanova',
#  'New Mexico',
#  'Washington',
#  'Florida State',
#  'Alabama',
#  'Richmond',
#  'Colorado',
#  'Illinois',
#  'George Mason',
#  'Memphis',
#  'USC',
#  'Michigan State',
#  'Virginia Tech',
#  'Texas A&M',
#  'Gonzaga',
#  'Georgia',
#  'Penn State',
#  'Xavier',
#  'UNLV',
#  'UCF',
#  'Missouri',
#  'Ole Miss',
#  'Alabama-Birmingham',
#  'Wichita State',
#  'Minnesota',
#  'Washington State',
#  'Michigan',
#  'Temple',
#  'Drexel',
#  'Clemson',
#  'Marshall',
#  'Oklahoma State',
#  'Valparaiso',
#  'Milwaukee',
#  "Saint Mary's (CA)",
#  'Morehead State',
#  'Arkansas',
#  'East Carolina',
#  'Nebraska',
#  'Oregon',
#  'Mississippi State',
#  'Seton Hall',
#  'Dayton',
#  'UTEP',
#  'Miami (FL)',
#  'University of California',
#  'College of Charleston',
#  'Cleveland State',
#  'Missouri State',
#  'Southern Miss',
#  'James Madison',
#  'Boston College',
#  'Tulsa',
#  'Utah State',
#  'South Carolina',
#  'Iona',
#  'Northern Iowa',
#  'Georgia Tech',
#  'Rhode Island',
#  'Providence',
#  'Northwestern',
#  'Kent State',
#  'Indiana State',
#  'Wright State',
#  'Coastal Carolina',
#  'Baylor',
#  'SMU',
#  'San Francisco',
#  'Colorado State',
#  'Jacksonville',
#  'Evansville',
#  'Hofstra',
#  'Santa Clara',
#  'Creighton',
#  'Maryland',
#  'Virginia',
#  'Harvard',
#  'Akron',
#  'Wofford',
#  'Murray State',
#  'Princeton',
#  'North Carolina-Asheville',
#  'Portland',
#  'ETSU',
#  'Iowa',
#  'Duquesne',
#  'Oregon State',
#  'Oakland',
#  'Montana',
#  'Belmont',
#  'Idaho',
#  'St. Bonaventure',
#  'Ohio',
#  'Long Beach State',
#  'North Carolina State',
#  'Austin Peay',
#  'Miami (OH)',
#  "St. Peter's",
#  'Davidson',
#  'Buffalo',
#  'Stanford',
#  'Florida Atlantic',
#  'Arizona State',
#  'Sam Houston State',
#  'Rutgers',
#  'UCSB',
#  'Bucknell',
#  'Northern Colorado',
#  'Fairfield',
#  'Utah',
#  'Boise State',
#  'Furman',
#  'UTSA',
#  'Detroit',
#  'Western Michigan',
#  'Green Bay',
#  'Rider',
#  'North Texas',
#  'Weber State',
#  'Stephen F. Austin',
#  'South Florida',
#  'UMass',
#  'Charlotte',
#  'Tennessee Tech',
#  'McNeese State',
#  'Delaware',
#  'Iowa State',
#  'San Jose State',
#  'Little Rock',
#  'Rice',
#  'Loyola (IL)',
#  'Hawaii',
#  'IUPUI',
#  'Houston',
#  'Northeastern',
#  'Pacific',
#  'Oklahoma',
#  'Georgia State',
#  'Air Force',
#  'Western Carolina',
#  'Southern Illinois',
#  'Hampton',
#  'Indiana',
#  'Youngstown State',
#  'LIU-Brooklyn',
#  'Texas State',
#  'Lipscomb',
#  'Auburn',
#  'Virginia Military Institute',
#  'Bethune-Cookman',
#  'Tennessee State',
#  'Texas Tech',
#  'George Washington',
#  'Eastern Kentucky',
#  'Chattanooga',
#  'Northern Arizona',
#  'Liberty',
#  'Oral Roberts',
#  'Saint Louis',
#  'Winthrop',
#  'Texas-Arlington',
#  'Ball State',
#  'Southeastern Louisiana',
#  'Northwestern State',
#  'South Dakota',
#  'Utah Valley',
#  'William & Mary',
#  'North Carolina-Wilmington',
#  'Appalachian State',
#  'New Mexico State',
#  'Yale',
#  'NJIT',
#  'Bradley',
#  'Robert Morris',
#  'Middle Tennessee',
#  'Vermont',
#  'South Dakota State',
#  'Charleston Southern',
#  'High Point',
#  'La Salle',
#  'Western Kentucky',
#  'Eastern Illinois',
#  'Maine',
#  'Gardner-Webb',
#  'Bowling Green State',
#  'Quinnipiac',
#  'Arkansas State',
#  'Boston University',
#  'Canisius',
#  'Nevada',
#  'Drake',
#  'Nicholls State',
#  'Florida A&M',
#  'Tulane',
#  'North Carolina A&T',
#  'Morgan State',
#  'North Dakota',
#  'Siena',
#  'Louisiana Tech',
#  'Coppin State',
#  'Montana State',
#  "St. Joseph's",
#  'Mercer',
#  'Presbyterian',
#  'Wyoming',
#  'Cal State Northridge',
#  'Fort Wayne',
#  'Elon',
#  'Pepperdine',
#  'Texas A&M-Corpus Christi',
#  'Eastern Washington',
#  'Savannah State',
#  'North Dakota State',
#  'LSU',
#  'Citadel',
#  'Denver',
#  'Brown',
#  'American',
#  'Fordham',
#  'UC-Riverside',
#  'Texas Christian',
#  'UMKC',
#  'Loyola (MD)',
#  'Portland State',
#  'Louisiana',
#  'Samford',
#  'Loyola Marymount',
#  'North Florida',
#  'North Carolina Central',
#  'Alabama State',
#  'Eastern Michigan',
#  'UIC',
#  'Cal Poly',
#  'Columbia',
#  'Florida International',
#  'Fresno State',
#  'Lamar',
#  'Seattle',
#  'Wagner',
#  'Lehigh',
#  'Central Connecticut',
#  'UC-Irvine',
#  'South Carolina State',
#  'Southern Illinois-Edwardsville',
#  'San Diego',
#  'Southeast Missouri State',
#  'Cal State Fullerton',
#  'Campbell',
#  'Bryant',
#  'Penn',
#  'Western Illinois',
#  'Troy',
#  'UT-Martin',
#  'Army',
#  'Alabama A&M',
#  'Radford',
#  'South Alabama',
#  'Stony Brook',
#  'DePaul',
#  'Longwood',
#  'Illinois State',
#  'Jackson State',
#  'Texas Southern',
#  'Lafayette',
#  'Cornell',
#  'Stetson',
#  'Louisiana-Monroe',
#  'Northern Illinois',
#  'Navy',
#  'St. Francis (NY)',
#  'Prairie View',
#  'Delaware State',
#  'Texas-Rio Grande Valley',
#  'UC-Davis',
#  'Saint Francis (PA)',
#  'Central Michigan',
#  'Norfolk State',
#  'Idaho State',
#  'Maryland-Eastern Shore',
#  'Albany (NY)',
#  'Wake Forest',
#  'Hartford',
#  'Cal State Bakersfield',
#  'Central Arkansas',
#  'New Hampshire',
#  'Florida Gulf Coast',
#  "Mount St. Mary's",
#  'Southern Utah',
#  'Chicago State',
#  'Niagara',
#  'Toledo',
#  'Sacred Heart',
#  'Jacksonville State',
#  'North Carolina-Greensboro',
#  'Sacramento State',
#  'Kennesaw State',
#  'South Carolina Upstate',
#  'Grambling',
#  'Monmouth',
#  'Mississippi Valley State',
#  'Georgia Southern',
#  'Houston Baptist',
#  'Holy Cross',
#  'Howard',
#  'Manhattan',
#  'Colgate',
#  'Towson',
#  'Marist',
#  'UMBC',
#  'Binghamton',
#  'Fairleigh Dickinson',
#  'Arkansas-Pine Bluff',
#  'Dartmouth',
#  'Southern',
#  'Alaska-Anchorage',
#  'Alcorn State',
#  'Louisiana State-Shreveport',
#  'Colorado College',
#  'Our Lady of the Lake',
#  'Chaminade',
#  'Texas College',
#  'Cal State Monterey Bay',
#  'Centenary (LA)',
#  'Palm Beach Atlantic',
#  'California Baptist',
#  'Olivet Nazarene',
#  'East Texas Baptist',
#  'Arkansas-Monticello',
#  'Tougaloo',
#  'Xavier (LA)',
#  'Millikin',
#  'Vassar',
#  'Texas A&M-Kingsville',
#  'West Florida',
#  'Concordia (IL)',
#  'Piedmont',
#  'Erskine',
#  'Florida Memorial',
#  'North Greenville',
#  'Georgia Southwestern',
#  'Lyon',
#  'Virginia Intermont',
#  'West Virginia Tech',
#  'Oglethorpe',
#  'Tennessee Temple',
#  'Truman State',
#  'Asbury',
#  'Johnson & Wales (NC)',
#  'Waldorf',
#  'Henderson State',
#  'Tabor College',
#  'St. Thomas (TX)',
#  'College of Idaho',
#  'Occidental',
#  'Brewton-Parker',
#  'Spring Hill',
#  'Millsaps',
#  'Howard Payne',
#  'MacMurray',
#  'Texas Lutheran',
#  'Huston-Tillotson',
#  'Sul Ross State',
#  'Huntington',
#  'Grand Canyon',
#  'Indiana-Northwest',
#  'Randolph',
#  'St. Francis (IL)',
#  'Talladega',
#  'Edward Waters',
#  'Western State',
#  'Marian (IN)',
#  'Hendrix',
#  'LaGrange',
#  'Washington Adventist',
#  'Bluefield (WV)',
#  'Oakland City',
#  'Mary Washington',
#  'Minnesota-Duluth',
#  'Ferrum',
#  'Farmingdale State',
#  'Eastern Oregon',
#  'West Alabama',
#  'Austin College',
#  'Lesley',
#  'Emory & Henry',
#  'Mary Hardin-Baylor',
#  'Northeastern State',
#  'Queens (NC)',
#  'Kean',
#  'Colorado-Colorado Springs',
#  'La Sierra',
#  'Methodist',
#  'Mount Ida College',
#  'Ohio Dominican',
#  'Pomona-Pitzer',
#  'Urbana',
#  'TCNJ',
#  'Southeastern',
#  'Barry',
#  'Carver Bible',
#  'Roosevelt',
#  'Stillman',
#  'San Francisco State',
#  'Louisiana College',
#  'Glenville State',
#  'Western New Mexico',
#  'NYU-Poly',
#  'Rockhurst',
#  'Northwest Oklahoma State',
#  'Tennessee Wesleyan',
#  'Fisk',
#  'Montreat',
#  'Neumann',
#  'North Carolina Wesleyan',
#  'Coe',
#  'Arlington Baptist',
#  'Bethany (CA)',
#  'Anderson (SC)',
#  'Texas-Tyler',
#  'Virginia Wise',
#  'Colorado Christian',
#  "St. Gregory's",
#  'UC-Santa Cruz',
#  'Madonna',
#  'Warner Southern',
#  'Vanguard',
#  'South Dakota School of Mines',
#  'Auburn Montgomery',
#  'Northwood (MI)',
#  'Northwest Washington',
#  'Reinhardt',
#  'Southern Virginia',
#  'Point Loma Nazarene',
#  'Southwest Minnesota State',
#  'Purdue North Central',
#  'Indiana Tech',
#  'Gwynedd-Mercy',
#  'Great Falls',
#  'Maine-Machias',
#  'Montana Tech',
#  'Minot State',
#  'Southwestern (AZ)',
#  'Texas A&M-International',
#  'Cameron',
#  'Tuskegee',
#  'Indiana-South Bend',
#  'Florida Tech',
#  'Southeastern Oklahoma State',
#  'Dowling',
#  'Mayville State',
#  'William Jessup',
#  'Cardinal Stritch',
#  'Hampden-Sydney',
#  'Hardin-Simmons',
#  'Maryville (MO)',
#  'Warren Wilson',
#  'Champion Baptist',
#  'Cincinnati Christian',
#  'Lenoir-Rhyne',
#  'American International',
#  'Wayland Baptist',
#  'SUNY-Cobleskill',
#  'Philadelphia Biblical',
#  'Greensboro',
#  'San Diego Christian',
#  'Milligan',
#  'Judson',
#  'Allen',
#  'Loyola (LA)',
#  'Science and Arts of Oklahoma',
#  "St. Edward's",
#  'Northern New Mexico',
#  'Lander',
#  'Johnson C. Smith',
#  'Webber',
#  'Indiana-East',
#  'Emporia State',
#  'Southern-New Orleans',
#  'Valley City State',
#  'Central Pennsylvania College',
#  'Toccoa Falls',
#  'Lincoln (PA)',
#  'Florida Christian',
#  'Susquehanna',
#  'Holy Names',
#  'Dillard',
#  'Brigham Young-Hawaii',
#  'Central Baptist',
#  'Martin Methodist',
#  'Notre Dame de Namur',
#  'Fayetteville State',
#  'New Hope Christian',
#  "St. Joseph's (NY)",
#  'Black Hills State',
#  'Ecclesia',
#  'Alma',
#  'Victory',
#  "St. Mary's (MD)",
#  'Concordia (MI)',
#  'Philander Smith',
#  'Cal Lutheran',
#  'Worcester Tech',
#  'Saginaw Valley State',
#  'St. Catharine',
#  'Kentucky Christian',
#  'Voorhees',
#  'Culver-Stockton',
#  'Jarvis Christian',
#  'Redlands',
#  'George Fox',
#  'Johnson & Wales (CO)',
#  'Fontbonne',
#  'Hawaii Pacific',
#  'Willamette',
#  'Cal State Stanislaus',
#  'Hannibal-LaGrange',
#  'Tusculum',
#  'Lynchburg',
#  'LeMoyne-Owen',
#  'Southwest Assemblies of God',
#  'La Verne',
#  'Malone',
#  'Trinity International (IL)',
#  'New Orleans',
#  'Panhandle State',
#  'Bethel (TN)',
#  'Missouri Valley',
#  'Oakwood',
#  'Lewis & Clark',
#  'King (TN)',
#  'Hiwassee',
#  'Shenandoah',
#  'Houghton',
#  'McMurry',
#  'University of the Southwest',
#  'William Woods',
#  'Thomas More',
#  'Rochester (MI)',
#  'Mount St. Joseph',
#  'Bluefield College (VA)',
#  'Washington College',
#  'Dallas Christian',
#  'Cornerstone',
#  'Puget Sound',
#  'Mobile',
#  'Brescia',
#  'Union (KY)',
#  'Midland Lutheran',
#  'Oberlin',
#  'Dominican (CA)',
#  'Dickinson College',
#  'Albany State (GA)',
#  "Saint Joseph's (ME)",
#  'Rogers State',
#  'Doane College',
#  "Crowley's Ridge",
#  'Fresno Pacific',
#  'Chowan',
#  'MIT',
#  'Purdue Calumet',
#  'Wilmington (DE)',
#  'Anderson (IN)',
#  'Wiley',
#  'Ferris State',
#  'Haskell Indian Nations Institute',
#  'North Alabama',
#  'Lyndon State',
#  'Union (NY)',
#  'Marywood',
#  'Baruch College',
#  'Wilberforce',
#  'City Tech',
#  'Greenville (IL)',
#  'Morris College',
#  'Robert Morris (IL)',
#  'Montana Western',
#  'Trinity Baptist']

# %% [markdown]
# ### NCAA Men's 2011 Rank

# %%
rank_ncaa_teams("ncaa2011.csv")
# Out:
# ['Kentucky',
#  'Indiana',
#  'Ohio State',
#  'Michigan State',
#  'Kansas',
#  'Vanderbilt',
#  'Syracuse',
#  'Louisville',
#  'Wisconsin',
#  'Duke',
#  'Michigan',
#  'Cincinnati',
#  'UNC',
#  'Marquette',
#  'Florida State',
#  'Missouri',
#  'Baylor',
#  'Notre Dame',
#  'Kansas State',
#  'Florida',
#  'Iowa',
#  'Georgetown',
#  'Iowa State',
#  'UNLV',
#  'Illinois',
#  'Purdue',
#  'Xavier',
#  'Temple',
#  'Creighton',
#  'New Mexico',
#  'Wichita State',
#  'Minnesota',
#  'South Florida',
#  'Gonzaga',
#  'UConn',
#  'Murray State',
#  'Memphis',
#  'San Diego State',
#  'West Virginia',
#  'UMass',
#  'Northwestern',
#  "Saint Mary's (CA)",
#  'Alabama',
#  'Ohio',
#  'Stanford',
#  'Saint Louis',
#  'North Carolina State',
#  'Colorado State',
#  'Southern Miss',
#  'Miami (FL)',
#  'Tennessee',
#  'VCU',
#  'Northern Iowa',
#  'Colorado',
#  'Mississippi State',
#  'Virginia',
#  'Davidson',
#  "St. Joseph's",
#  'Dayton',
#  'Marshall',
#  'Seton Hall',
#  'University of California',
#  'BYU',
#  'Texas',
#  'Oregon',
#  'Arkansas',
#  'Tennessee State',
#  'Washington',
#  'Texas Christian',
#  'Nevada',
#  'Norfolk State',
#  'Illinois State',
#  'Pitt',
#  'LSU',
#  'Oklahoma State',
#  'Harvard',
#  'Cleveland State',
#  'Middle Tennessee',
#  'Georgia',
#  'Arizona',
#  'Loyola Marymount',
#  'Nebraska',
#  'Ole Miss',
#  'New Mexico State',
#  'Lehigh',
#  'Rutgers',
#  'Drexel',
#  'Valparaiso',
#  'Princeton',
#  'South Dakota State',
#  'Akron',
#  'Denver',
#  'UCF',
#  'Indiana State',
#  'Oregon State',
#  'Drake',
#  'Oral Roberts',
#  'Wyoming',
#  'Missouri State',
#  'St. Bonaventure',
#  'Butler',
#  'Evansville',
#  'Belmont',
#  'College of Charleston',
#  "St. John's (NY)",
#  'Iona',
#  'Clemson',
#  'Oklahoma',
#  'La Salle',
#  'Washington State',
#  'Utah State',
#  'Duquesne',
#  'Detroit',
#  'Long Beach State',
#  'Kent State',
#  'Bowling Green State',
#  'Idaho',
#  'George Mason',
#  'UTEP',
#  'Penn',
#  'Mercer',
#  'Montana',
#  'Robert Morris',
#  'Buffalo',
#  'Richmond',
#  'Oakland',
#  'UCLA',
#  'Tulsa',
#  'Virginia Tech',
#  'San Francisco',
#  'Maryland',
#  'Georgia State',
#  'Alabama-Birmingham',
#  'Texas-Arlington',
#  'Penn State',
#  'North Dakota',
#  'Providence',
#  'North Carolina-Asheville',
#  'Western Kentucky',
#  'Stephen F. Austin',
#  'UTSA',
#  'Coastal Carolina',
#  'Green Bay',
#  'Bucknell',
#  'Youngstown State',
#  'Old Dominion',
#  'Houston',
#  'Milwaukee',
#  'Weber State',
#  'Louisiana Tech',
#  'Lamar',
#  'Rice',
#  'Auburn',
#  'Western Illinois',
#  'Toledo',
#  'Hawaii',
#  'Fairfield',
#  'Tennessee Tech',
#  'Morehead State',
#  'South Carolina Upstate',
#  'Delaware',
#  'LIU-Brooklyn',
#  'Little Rock',
#  'Wagner',
#  'East Carolina',
#  'North Texas',
#  'Georgia Tech',
#  'McNeese State',
#  'Loyola (MD)',
#  'Villanova',
#  'Cal State Fullerton',
#  'Utah Valley',
#  'Delaware State',
#  'Charleston Southern',
#  'Wofford',
#  'Campbell',
#  'Louisiana',
#  'UCSB',
#  'Northwestern State',
#  'Samford',
#  'Presbyterian',
#  'IUPUI',
#  'Yale',
#  'Boise State',
#  'Boston College',
#  'Air Force',
#  'SMU',
#  'Western Carolina',
#  'Charlotte',
#  'Florida Atlantic',
#  'Miami (OH)',
#  'American',
#  'Elon',
#  'South Alabama',
#  'Arkansas State',
#  'Texas State',
#  'Eastern Michigan',
#  'NJIT',
#  'Santa Clara',
#  'Rhode Island',
#  'North Dakota State',
#  'Texas A&M',
#  'Columbia',
#  'North Carolina Central',
#  'Eastern Kentucky',
#  'Georgia Southern',
#  'High Point',
#  'Fresno State',
#  'Jacksonville State',
#  'Savannah State',
#  'South Carolina',
#  'Cornell',
#  'Chattanooga',
#  'Fordham',
#  'Furman',
#  'Wake Forest',
#  'Texas-Rio Grande Valley',
#  'Wright State',
#  'North Carolina-Greensboro',
#  'Vermont',
#  'Appalachian State',
#  'Holy Cross',
#  'South Dakota',
#  'Siena',
#  'UC-Riverside',
#  'Western Michigan',
#  'Manhattan',
#  'Austin Peay',
#  'Cal State Bakersfield',
#  'Florida Gulf Coast',
#  'Coppin State',
#  'Southern Utah',
#  'ETSU',
#  'Portland State',
#  'George Washington',
#  'Liberty',
#  'Stony Brook',
#  'Northeastern',
#  'Quinnipiac',
#  'Houston Baptist',
#  'Eastern Washington',
#  'Florida International',
#  'Cal Poly',
#  'Virginia Military Institute',
#  'Hofstra',
#  'DePaul',
#  'Mississippi Valley State',
#  'Arizona State',
#  'Seattle',
#  'Pacific',
#  'North Florida',
#  'Ball State',
#  'Tulane',
#  'Bethune-Cookman',
#  'Prairie View',
#  'Southeast Missouri State',
#  'Lipscomb',
#  'Gardner-Webb',
#  'Sam Houston State',
#  'Southeastern Louisiana',
#  'San Diego',
#  'Florida A&M',
#  'Fort Wayne',
#  'Southern Illinois-Edwardsville',
#  'Troy',
#  'Winthrop',
#  'Bradley',
#  'Alcorn State',
#  'UC-Irvine',
#  'North Carolina-Wilmington',
#  'North Carolina A&T',
#  'Pepperdine',
#  'UIC',
#  'Southern',
#  'San Jose State',
#  'Montana State',
#  'Southern Illinois',
#  'Central Michigan',
#  'St. Francis (NY)',
#  'Eastern Illinois',
#  'UMKC',
#  'Idaho State',
#  'Boston University',
#  'Sacramento State',
#  'Maine',
#  'Central Connecticut',
#  'Nicholls State',
#  'Morgan State',
#  'Utah',
#  'Rider',
#  'Central Arkansas',
#  'Texas Tech',
#  'Longwood',
#  'Alabama A&M',
#  'Alabama State',
#  'Marist',
#  'Howard',
#  'Jacksonville',
#  'Stetson',
#  'Portland',
#  'New Hampshire',
#  'Maryland-Eastern Shore',
#  'Texas Southern',
#  'Army',
#  'Niagara',
#  'Sacred Heart',
#  'Lafayette',
#  'Radford',
#  'Hampton',
#  'Northern Colorado',
#  'Albany (NY)',
#  'Monmouth',
#  'James Madison',
#  'Loyola (IL)',
#  'Texas A&M-Corpus Christi',
#  'Brown',
#  'Arkansas-Pine Bluff',
#  'Jackson State',
#  'Cal State Northridge',
#  'USC',
#  'Northern Arizona',
#  'William & Mary',
#  'UT-Martin',
#  'Northern Illinois',
#  'Citadel',
#  'South Carolina State',
#  'UC-Davis',
#  'Chicago State',
#  'Elizabeth City State',
#  'Colgate',
#  'Dartmouth',
#  'Navy',
#  'Saint Francis (PA)',
#  'Hartford',
#  "Mount St. Mary's",
#  'Louisiana-Monroe',
#  "St. Peter's",
#  'Canisius',
#  'Kennesaw State',
#  'Grambling',
#  'Binghamton',
#  'Fairleigh Dickinson',
#  'UMBC',
#  'San Francisco State',
#  'Texas Wesleyan',
#  'Alaska-Anchorage',
#  'Towson',
#  'New Orleans',
#  'Quincy',
#  'Bryant',
#  'Northwest Missouri State',
#  'Ohio Dominican',
#  'Philander Smith',
#  'Westminster (UT)',
#  'Omaha',
#  'Urbana',
#  'Harding',
#  'Lees-McRae',
#  'Colorado Christian',
#  'Johnson & Wales (RI)',
#  'Redlands',
#  'Cal Lutheran',
#  'Chapman',
#  'Covenant',
#  'Fort Lewis',
#  'Cheyney',
#  'Guilford',
#  'Lake Erie',
#  'Milligan',
#  'Roanoke',
#  'Mary',
#  'MIT',
#  'Anderson (IN)',
#  'Miles',
#  'Randolph',
#  'Fort Valley State',
#  'Ferris State',
#  'Harris-Stowe',
#  'Grand Canyon',
#  'Suffolk',
#  "St. Gregory's",
#  'LeTourneau',
#  'Montreat',
#  'Menlo',
#  'Fresno Pacific',
#  'UC-Merced',
#  'Claflin',
#  'Dillard',
#  'McMurry',
#  'Centenary (LA)',
#  'Texas Lutheran',
#  'Simpson (CA)',
#  'Northern New Mexico',
#  'Hiram',
#  'Blue Mountain College',
#  'St. Thomas (FL)',
#  'Methodist',
#  'Wilmington (DE)',
#  'Upper Iowa',
#  'Bridgewater (VA)',
#  'Emory',
#  'Southwest State (MN)',
#  'Waldorf',
#  'Pomona-Pitzer',
#  'Shenandoah',
#  'Howard Payne',
#  'Spring Hill',
#  'Western State',
#  'Virginia Intermont',
#  'Mississippi College',
#  'Penn State-Altoona',
#  'Johnson & Wales (NC)',
#  'Cal State Monterey Bay',
#  'Schreiner',
#  'Mount Ida College',
#  'LaGrange',
#  'Emory & Henry',
#  'Kenyon',
#  'Talladega',
#  'Ave Maria',
#  'Washington Adventist',
#  'Concordia (OR)',
#  'Maine-Machias',
#  'Great Falls',
#  'Penn State-Abington',
#  'West Alabama',
#  'Piedmont',
#  'East Texas Baptist',
#  'Austin College',
#  'San Diego Christian',
#  'Holy Cross (IN)',
#  'Brigham Young-Hawaii',
#  'UC-Santa Cruz',
#  'Bluefield College (VA)',
#  'Rio Grande',
#  'Louisiana College',
#  'Arlington Baptist',
#  'Reinhardt',
#  'Alice Lloyd',
#  'Notre Dame (OH)',
#  'Marywood',
#  'Roosevelt',
#  'Mars Hill',
#  'Central Pennsylvania College',
#  'Mobile',
#  'Webber',
#  'Florida Southern',
#  'Fisk',
#  'Florida Christian',
#  'Coker',
#  'Asbury',
#  'Tennessee Temple',
#  'North Carolina-Pembroke',
#  'Montana State-Billings',
#  'Lyndon State',
#  'Westmont',
#  'Spalding',
#  'Concordia (MI)',
#  'District of Columbia',
#  'Rutgers-Camden',
#  'Arizona Christian',
#  'Oakwood',
#  'Oakland City',
#  'Emporia State',
#  'Saint Leo',
#  'Rochester (MI)',
#  'Indiana-Kokomo',
#  'Concordia (AL)',
#  'NYU-Poly',
#  'Chaminade',
#  'Warren Wilson',
#  'Judson',
#  'Brevard',
#  'Cal State Dominguez Hills',
#  'Linfield',
#  'Saginaw Valley State',
#  'Victory',
#  'Ecclesia',
#  'Cumberland University',
#  'Holy Names',
#  'Greenville (IL)',
#  'Philadelphia Biblical',
#  'Eureka',
#  'Lewis & Clark',
#  'Morris College',
#  'Hannibal-LaGrange',
#  'Southern Virginia',
#  'Barber-Scotia',
#  'Chowan',
#  'Calumet College',
#  'Wilberforce',
#  'Cameron',
#  'Northwest Oklahoma State',
#  'Trevecca Nazarene',
#  'Swarthmore',
#  'Evergreen State',
#  'Tabor College',
#  'Southern Wesleyan',
#  'Dallas Christian',
#  'Academy of Art',
#  'Jamestown',
#  'Robert Morris (IL)',
#  'Wiley',
#  'Hope',
#  'Paul Quinn',
#  'La Sierra',
#  'Haskell Indian Nations Institute',
#  'West Virginia Tech',
#  'Brescia',
#  'Johnson & Wales (CO)',
#  'Walla Walla',
#  'St. Thomas (TX)',
#  'Mid-Continent',
#  'Langston',
#  'Pacific Union',
#  'Allen',
#  'Virginia Wise',
#  'Fredonia State',
#  'Malone',
#  'Cal State San Marcos',
#  'Henderson State',
#  'Montana Tech',
#  'Willamette',
#  'Southeastern',
#  'Loyola (LA)',
#  'MacMurray',
#  'Vanguard',
#  'Warner Southern',
#  'Averett',
#  'Maryville (MO)',
#  'Mercy',
#  'Bacone',
#  'Cal State Maritime',
#  'Illinois-Springfield',
#  'Lindsey Wilson',
#  'Texas A&M-International',
#  'Lynchburg',
#  'Arcadia',
#  "St. Joseph's (NY)",
#  'Coastal Georgia',
#  'Dakota State',
#  'Atlanta Christian',
#  'Michigan Tech',
#  'Pacifica',
#  'Bethel (TN)',
#  'Huston-Tillotson',
#  'Western New Mexico',
#  'Marietta',
#  'Wentworth',
#  'Wesley',
#  'Pacific Lutheran',
#  'Hawaii-Hilo',
#  "Saint Joseph's (IN)",
#  'Sioux Falls',
#  'La Verne',
#  'Mayville State',
#  'Missouri Valley',
#  'Texas College',
#  'Western Oregon',
#  'Lyon',
#  'Eastern New Mexico',
#  'Rockhurst',
#  'Loras',
#  'Central Methodist',
#  'LeMoyne-Owen',
#  'Newman',
#  'Rust',
#  'Hiwassee',
#  'Rogers State',
#  'Peru State',
#  'Hope International',
#  'Belhaven (MS)',
#  'Erskine',
#  'Cedarville',
#  'Arkansas Tech',
#  'Palm Beach Atlantic',
#  'Texas-Tyler',
#  'Brewton-Parker',
#  'Shawnee State',
#  'Jarvis Christian',
#  'Carver Bible',
#  'SUNY-Oswego',
#  'Indiana-Northwest',
#  'Buffalo State',
#  'Albright',
#  'TCNJ',
#  'Champion Baptist',
#  "Crowley's Ridge",
#  'Valley City State',
#  'SUNY-Cobleskill',
#  'St. Francis (IL)',
#  'Saint Mary (KS)',
#  'Toccoa Falls',
#  'Trinity Baptist',
#  'Northwest University']

# %% [markdown]
# ### NCAA Men's 2012 Rank

# %%
rank_ncaa_teams("ncaa2012.csv")
# Out:
# ['Louisville',
#  'Duke',
#  'Michigan',
#  'Syracuse',
#  'Indiana',
#  'Ohio State',
#  'Wisconsin',
#  'Michigan State',
#  'Miami (FL)',
#  'Georgetown',
#  'Marquette',
#  'Kansas',
#  'Wichita State',
#  'Butler',
#  'Illinois',
#  'Saint Louis',
#  'Villanova',
#  'New Mexico',
#  'Minnesota',
#  'Notre Dame',
#  'Florida',
#  'Creighton',
#  'Maryland',
#  'Arizona',
#  'Oregon',
#  'Virginia',
#  'UCLA',
#  'UNLV',
#  'Temple',
#  'Gonzaga',
#  'North Carolina State',
#  'VCU',
#  'UNC',
#  'Pitt',
#  'Indiana State',
#  'Oklahoma State',
#  'University of California',
#  'Iowa',
#  'Colorado',
#  'San Diego State',
#  'Cincinnati',
#  'UConn',
#  'Ole Miss',
#  'Colorado State',
#  'La Salle',
#  'Kansas State',
#  'Xavier',
#  'Missouri',
#  'Baylor',
#  'Memphis',
#  'Iowa State',
#  'Florida Gulf Coast',
#  'Evansville',
#  'Oklahoma',
#  'Northern Iowa',
#  'Tennessee',
#  "Saint Mary's (CA)",
#  'Boise State',
#  'Kentucky',
#  'Alabama',
#  'Stanford',
#  'Air Force',
#  'Florida State',
#  'South Dakota State',
#  'Providence',
#  'Georgia Tech',
#  'Belmont',
#  'Charlotte',
#  'Washington',
#  'Arizona State',
#  'UMass',
#  'Santa Clara',
#  'Arkansas',
#  'Wake Forest',
#  'Utah',
#  'Southern Miss',
#  'Purdue',
#  'BYU',
#  'Texas A&M',
#  "St. John's (NY)",
#  'Valparaiso',
#  'Drake',
#  'USC',
#  'Illinois State',
#  'Harvard',
#  "St. Joseph's",
#  'Akron',
#  'Northwestern State',
#  'East Carolina',
#  'Pacific',
#  'Southern Illinois',
#  'Murray State',
#  'South Florida',
#  'Green Bay',
#  'Wyoming',
#  'Detroit',
#  'Bucknell',
#  'Mercer',
#  'Stephen F. Austin',
#  'LSU',
#  'Richmond',
#  'Weber State',
#  'Boston College',
#  'Middle Tennessee',
#  'Nebraska',
#  'Louisiana Tech',
#  'George Mason',
#  'UCF',
#  'UIC',
#  'UTEP',
#  'Texas',
#  'Penn State',
#  'Georgia',
#  'New Mexico State',
#  'Texas Christian',
#  'Denver',
#  'Fresno State',
#  'Dayton',
#  'Wright State',
#  'North Dakota State',
#  'Davidson',
#  'Northwestern',
#  'Eastern Kentucky',
#  'Bradley',
#  'Vanderbilt',
#  'Northeastern',
#  'Tennessee State',
#  'Stony Brook',
#  'Cal Poly',
#  'Montana',
#  'Virginia Tech',
#  'Princeton',
#  'Kent State',
#  'Iona',
#  'Canisius',
#  'Youngstown State',
#  'Western Michigan',
#  'Western Illinois',
#  'Utah State',
#  'Missouri State',
#  'Ohio',
#  'St. Bonaventure',
#  'Rutgers',
#  'Gardner-Webb',
#  'Oakland',
#  'UC-Irvine',
#  'College of Charleston',
#  'Seton Hall',
#  'Lafayette',
#  'Long Beach State',
#  'Vermont',
#  'Loyola (MD)',
#  'Robert Morris',
#  'Delaware',
#  'Niagara',
#  'Rhode Island',
#  'Oregon State',
#  'Nevada',
#  'Albany (NY)',
#  'Clemson',
#  'Morehead State',
#  'Buffalo',
#  'Columbia',
#  'South Carolina',
#  'San Francisco',
#  'Cleveland State',
#  'Tulsa',
#  'Arkansas State',
#  'Tulane',
#  'Lehigh',
#  'Oral Roberts',
#  'James Madison',
#  'Texas-Arlington',
#  'Rider',
#  'Marshall',
#  'Charleston Southern',
#  'Washington State',
#  'Yale',
#  'Florida International',
#  'Elon',
#  'George Washington',
#  'Lipscomb',
#  'Georgia State',
#  'Alabama-Birmingham',
#  'Eastern Michigan',
#  'NJIT',
#  'Loyola (IL)',
#  'North Carolina-Asheville',
#  'Bowling Green State',
#  'Towson',
#  'Bryant',
#  'Brown',
#  'Fairfield',
#  'South Dakota',
#  'Houston',
#  'Western Kentucky',
#  'Coastal Carolina',
#  'San Diego',
#  'Cal State Bakersfield',
#  'UCSB',
#  'Wagner',
#  'Jacksonville State',
#  'Maine',
#  'North Carolina A&T',
#  'LIU-Brooklyn',
#  'Campbell',
#  'Savannah State',
#  'North Carolina Central',
#  'Hawaii',
#  'West Virginia',
#  'Montana State',
#  'Chicago State',
#  'Boston University',
#  'Sam Houston State',
#  'Georgia Southern',
#  'Central Connecticut',
#  'Winthrop',
#  'Duquesne',
#  'Ball State',
#  'Stetson',
#  'Southeast Missouri State',
#  'South Alabama',
#  "Mount St. Mary's",
#  'Drexel',
#  'Hartford',
#  'Quinnipiac',
#  'Southeastern Louisiana',
#  'Little Rock',
#  'Cal State Northridge',
#  'Auburn',
#  'Liberty',
#  'Mississippi State',
#  'Delaware State',
#  'McNeese State',
#  'North Dakota',
#  'Wofford',
#  'Loyola Marymount',
#  'Milwaukee',
#  'SMU',
#  'Southern Illinois-Edwardsville',
#  'Southern',
#  'Sacramento State',
#  'Manhattan',
#  'South Carolina Upstate',
#  'Houston Baptist',
#  'Cal State Fullerton',
#  'High Point',
#  'Florida Atlantic',
#  'Jacksonville',
#  'Army',
#  'Utah Valley',
#  'Texas-Rio Grande Valley',
#  'UT-Martin',
#  'Fort Wayne',
#  'UC-Davis',
#  'Western Carolina',
#  'Virginia Military Institute',
#  'St. Francis (NY)',
#  'DePaul',
#  'Toledo',
#  'San Jose State',
#  'Tennessee Tech',
#  'Central Michigan',
#  'ETSU',
#  'Portland',
#  'Norfolk State',
#  'North Carolina-Wilmington',
#  'Texas Tech',
#  'Cornell',
#  'Pepperdine',
#  'Louisiana',
#  'North Texas',
#  'Chattanooga',
#  'William & Mary',
#  'Northern Colorado',
#  'Central Arkansas',
#  'Marist',
#  'Penn',
#  'Old Dominion',
#  'Prairie View',
#  'Miami (OH)',
#  'Eastern Illinois',
#  'Radford',
#  'Appalachian State',
#  'North Florida',
#  'Dartmouth',
#  'Troy',
#  'North Carolina-Greensboro',
#  'Sacred Heart',
#  'UC-Riverside',
#  'Idaho',
#  'Morgan State',
#  'IUPUI',
#  'UTSA',
#  'Bethune-Cookman',
#  'Texas State',
#  'Hofstra',
#  'New Orleans',
#  'Samford',
#  'Portland State',
#  'Presbyterian',
#  'Nicholls State',
#  "St. Peter's",
#  'Northern Kentucky',
#  'Hampton',
#  'New Hampshire',
#  'UMBC',
#  'Northern Arizona',
#  'UMKC',
#  'Holy Cross',
#  'Navy',
#  'Seattle',
#  'Alabama A&M',
#  'South Carolina State',
#  'Texas Southern',
#  'Monmouth',
#  'Southern Utah',
#  'Omaha',
#  'Austin Peay',
#  'Fordham',
#  'Longwood',
#  'Furman',
#  'Colgate',
#  'Arkansas-Pine Bluff',
#  'Coppin State',
#  'Idaho State',
#  'Rice',
#  'American',
#  'Eastern Washington',
#  'Texas A&M-Corpus Christi',
#  'Siena',
#  'Alcorn State',
#  'Citadel',
#  'Alabama State',
#  'Northern Illinois',
#  'Fairleigh Dickinson',
#  'Florida A&M',
#  'Howard',
#  'Binghamton',
#  'Kennesaw State',
#  'Jackson State',
#  'Saint Francis (PA)',
#  'Louisiana-Monroe',
#  'Anderson (SC)',
#  'Lamar',
#  'Mississippi Valley State',
#  'Chaminade',
#  'Maryland-Eastern Shore',
#  'Alaska-Anchorage',
#  'Rio Grande',
#  'Alabama-Huntsville',
#  'Rochester (MI)',
#  'Saint Mary (KS)',
#  'Fort Valley State',
#  'St. Thomas (TX)',
#  'Lincoln (PA)',
#  'Miles',
#  'Montreat',
#  'Lake Erie',
#  'Averett',
#  'Claflin',
#  'Grambling',
#  'Emory',
#  'Northern Michigan',
#  'Cincinnati Christian',
#  'MIT',
#  'Reinhardt',
#  'Pacifica',
#  'Louisiana College',
#  'Slippery Rock',
#  'Mary',
#  'Philander Smith',
#  'Brescia',
#  'Marymount (VA)',
#  'Greensboro',
#  'Valley City State',
#  'East Texas Baptist',
#  'Albion',
#  'Pacific (OR)',
#  'UC-Merced',
#  'San Diego Christian',
#  'Trinity Baptist',
#  'Howard Payne',
#  'Willamette',
#  'District of Columbia',
#  'Arizona Christian',
#  'Young Harris',
#  'Gwynedd-Mercy',
#  'William Jewell',
#  'Washington & Lee',
#  'Covenant',
#  'North Alabama',
#  'Sewanee',
#  'Suffolk',
#  'Edward Waters',
#  'University of the Southwest',
#  'Wartburg',
#  'Holy Names',
#  'Sonoma State',
#  'Simpson (CA)',
#  "Crowley's Ridge",
#  'Texas Lutheran',
#  'Wabash',
#  'St. Andrews',
#  'Western State',
#  'West Alabama',
#  'Oakwood',
#  'Schreiner',
#  'Mount Ida College',
#  'Louisiana State-Shreveport',
#  'Mars Hill',
#  'John Carroll',
#  'Tennessee Temple',
#  'Cairn',
#  'Maryville (MO)',
#  'Rockhurst',
#  'Eastern',
#  'Oglethorpe',
#  'Johnson & Wales (NC)',
#  'Winston-Salem',
#  'Martin Methodist',
#  'Hiwassee',
#  'Lyon',
#  'Centenary (LA)',
#  'Webber',
#  'Arkansas-Monticello',
#  'Hendrix',
#  'Concordia (IL)',
#  'Haverford',
#  'Methodist',
#  'Bridgewater (VA)',
#  'Southern Wesleyan',
#  'Lincoln (MO)',
#  'Eastern Nazarene',
#  'Arlington Baptist',
#  'Hardin-Simmons',
#  'Cal State East Bay',
#  'Texas-Tyler',
#  'Central Pennsylvania College',
#  'Marygrove',
#  'Minot State',
#  'Crown College',
#  "St. Gregory's",
#  "St. Edward's",
#  'William Carey',
#  'Fontbonne',
#  'Chadron State',
#  'Ave Maria',
#  'Alice Lloyd',
#  'Olivet College',
#  'Cameron',
#  'Whitman',
#  "Master's",
#  'Union (KY)',
#  'Dallas Christian',
#  'Truman State',
#  'Mayville State',
#  'Hannibal-LaGrange',
#  'Benedictine-Springfield',
#  'Regis (CO)',
#  'Judson',
#  'Brevard',
#  'Malone',
#  'Southeastern',
#  'Westmont',
#  'Blue Mountain College',
#  'Toccoa Falls',
#  'UC-Santa Cruz',
#  'Jarvis Christian',
#  'Lenoir-Rhyne',
#  'Southern-New Orleans',
#  'Northern New Mexico',
#  'Pacific Lutheran',
#  'Southwest State (MN)',
#  'Carroll (MT)',
#  'Wayland Baptist',
#  'Culver-Stockton',
#  'Marywood',
#  'Mansfield',
#  'Cheyney',
#  'Madonna',
#  'Waldorf',
#  'Wilmington (DE)',
#  'Indiana-East',
#  'Fisk',
#  'Hanover',
#  'Lyndon State',
#  'Lewis & Clark',
#  'Dominican (CA)',
#  'Loyola (LA)',
#  'Berea',
#  'Newberry',
#  'Trinity Christian',
#  'Milligan',
#  'Montana Western',
#  'Florida Tech',
#  'Barber-Scotia',
#  'Champion Baptist',
#  'Virginia Wise',
#  'Florida Christian',
#  'Virginia-Lynchburg',
#  'Southern Virginia',
#  'Bethel (TN)',
#  'Oakland City',
#  'Holy Cross (IN)',
#  'Vanguard',
#  'Roosevelt',
#  'Coker',
#  'Fisher College',
#  'Montana Tech',
#  'Dakota State',
#  'Geneva',
#  'Menlo',
#  'Allen',
#  'Brewton-Parker',
#  'Southern Poly',
#  'Pacific Union',
#  'Western Oregon',
#  'Panhandle State',
#  'Hiram',
#  'Warner Southern',
#  'Indiana-Northwest',
#  'North Greenville',
#  'La Verne',
#  'Presentation College',
#  'Eureka',
#  'Eastern New Mexico',
#  'Portland Bible College',
#  'Walla Walla',
#  'Brigham Young-Hawaii',
#  'Tuskegee',
#  'Missouri Valley',
#  'George Fox',
#  'Lubbock Christian',
#  'LeMoyne-Owen',
#  'Tabor College',
#  'Whittier',
#  'Arcadia',
#  'Benedictine (IL)',
#  'Point Loma Nazarene',
#  'Albertus Magnus',
#  'Notre Dame (OH)',
#  'Huston-Tillotson',
#  'Robert Morris (IL)',
#  'Cal State San Marcos',
#  'Cal State Maritime',
#  'Salisbury',
#  'Rosemont',
#  'Hope International',
#  'Spalding',
#  'CCNY',
#  'Purdue Calumet',
#  'Siena Heights',
#  'Fresno Pacific',
#  'Spring Hill',
#  'College of Idaho',
#  'Auburn Montgomery',
#  'Virginia Intermont',
#  'Adams State',
#  'Ohio Dominican',
#  'Northwest Indian College',
#  'Corban',
#  'Illinois-Springfield',
#  'Fairmont State',
#  'Wilmington (OH)',
#  'Bluefield College (VA)',
#  'Coastal Georgia',
#  'Mount St. Joseph',
#  'Central Baptist',
#  'Manchester',
#  'LeTourneau',
#  'Shenandoah',
#  'Dillard',
#  'North Carolina Wesleyan',
#  'Warren Wilson',
#  'Muhlenburg',
#  'Lees-McRae',
#  'Greenville (IL)',
#  'Daniel Webster',
#  'Old Westbury',
#  'Oberlin',
#  'Colby-Sawyer',
#  'Ecclesia',
#  'TCNJ',
#  'Peru State',
#  'Urbana',
#  'Georgia Southwestern']

# %% [markdown]
# ### NCAA Men's 2013 Rank

# %%
rank_ncaa_teams("ncaa2013.csv")
# Out:
# ['UConn',
#  'Wisconsin',
#  'Kentucky',
#  'Arizona',
#  'Florida',
#  'Louisville',
#  'Michigan State',
#  'Michigan',
#  'UCLA',
#  'Kansas',
#  'Iowa State',
#  'Cincinnati',
#  'SMU',
#  'Duke',
#  'Stanford',
#  'Baylor',
#  'Virginia',
#  'UNC',
#  'Syracuse',
#  'Texas',
#  'Ohio State',
#  'Memphis',
#  'Oregon',
#  'Creighton',
#  'Minnesota',
#  'Dayton',
#  'Oklahoma',
#  'University of California',
#  'Arizona State',
#  'Nebraska',
#  'New Mexico',
#  'San Diego State',
#  'Villanova',
#  'Colorado',
#  'Arkansas',
#  'Kansas State',
#  'VCU',
#  'UMass',
#  'Tennessee',
#  'Indiana',
#  'Oklahoma State',
#  'Wichita State',
#  "St. Joseph's",
#  'Saint Louis',
#  'Pitt',
#  'Missouri',
#  'Georgetown',
#  'Xavier',
#  'Iowa',
#  'Illinois',
#  'North Carolina State',
#  'Gonzaga',
#  'George Washington',
#  'BYU',
#  'Florida State',
#  'West Virginia',
#  'Providence',
#  'Southern Miss',
#  'Houston',
#  'LSU',
#  'Clemson',
#  'Utah',
#  'Louisiana Tech',
#  'Northwestern',
#  'Oregon State',
#  'Harvard',
#  'North Dakota State',
#  'Green Bay',
#  'Washington',
#  "Saint Mary's (CA)",
#  'Wake Forest',
#  'Maryland',
#  'Georgia',
#  'Seton Hall',
#  'Belmont',
#  'Penn State',
#  'Stephen F. Austin',
#  "St. John's (NY)",
#  'Tulsa',
#  'Charlotte',
#  'Alabama-Birmingham',
#  'Ohio',
#  'Boise State',
#  'South Carolina',
#  'Mercer',
#  'Richmond',
#  'Toledo',
#  'Western Michigan',
#  'Texas Tech',
#  'UTEP',
#  'Miami (FL)',
#  'Texas A&M',
#  'Eastern Michigan',
#  'Middle Tennessee',
#  'Georgia Tech',
#  'New Mexico State',
#  'Wyoming',
#  'St. Bonaventure',
#  'Louisiana',
#  'Ole Miss',
#  'Marquette',
#  'UNLV',
#  'Purdue',
#  'Milwaukee',
#  'Notre Dame',
#  'Georgia State',
#  'San Francisco',
#  'UCSB',
#  'Fort Wayne',
#  'Virginia Military Institute',
#  'Akron',
#  'Illinois State',
#  'Alabama',
#  'Vanderbilt',
#  'Fresno State',
#  'East Carolina',
#  'San Diego',
#  'Washington State',
#  'ETSU',
#  'Northern Iowa',
#  'Incarnate Word',
#  'Cleveland State',
#  'Buffalo',
#  'Western Kentucky',
#  'Yale',
#  'Rhode Island',
#  'Pacific',
#  'Eastern Kentucky',
#  'South Dakota State',
#  'Indiana State',
#  'Hawaii',
#  'Boston College',
#  'Valparaiso',
#  'La Salle',
#  'Portland',
#  'Manhattan',
#  'North Dakota',
#  'Denver',
#  'Utah State',
#  'UC-Irvine',
#  'Temple',
#  'USC',
#  'Wright State',
#  'Coastal Carolina',
#  'Nevada',
#  'Murray State',
#  'Missouri State',
#  'Florida Atlantic',
#  'Cal Poly',
#  'Florida Gulf Coast',
#  'Northern Colorado',
#  'North Carolina Central',
#  'Winthrop',
#  'Colorado State',
#  'North Texas',
#  'Cal State Northridge',
#  'South Carolina Upstate',
#  'Delaware',
#  'Princeton',
#  'DePaul',
#  'George Mason',
#  'Columbia',
#  'Morehead State',
#  'Towson',
#  'Auburn',
#  'Canisius',
#  'Sam Houston State',
#  'Montana',
#  'South Florida',
#  'Iona',
#  'Pepperdine',
#  'Bowling Green State',
#  'Siena',
#  'Youngstown State',
#  'Boston University',
#  'Elon',
#  'Radford',
#  'Butler',
#  'Quinnipiac',
#  'High Point',
#  'Tulane',
#  'Utah Valley',
#  'Weber State',
#  'Gardner-Webb',
#  'Kent State',
#  'Davidson',
#  'Western Carolina',
#  'Tennessee Tech',
#  'North Florida',
#  'Old Dominion',
#  'Northern Illinois',
#  'Oral Roberts',
#  'Long Beach State',
#  'Duquesne',
#  'Santa Clara',
#  'William & Mary',
#  'Evansville',
#  'Wofford',
#  'Loyola Marymount',
#  'Northwestern State',
#  'Florida International',
#  'Idaho',
#  'Oakland',
#  'Portland State',
#  'Southern Illinois',
#  'Robert Morris',
#  'Detroit',
#  'Drake',
#  'Little Rock',
#  'Vermont',
#  'St. Francis (NY)',
#  'North Carolina-Asheville',
#  'Eastern Washington',
#  'UCF',
#  'Arkansas State',
#  'Chattanooga',
#  'Alabama State',
#  'Miami (OH)',
#  'Air Force',
#  'Chicago State',
#  'Montana State',
#  'Southern',
#  'Omaha',
#  'Drexel',
#  'Troy',
#  'Charleston Southern',
#  'Stony Brook',
#  'South Dakota',
#  'Abilene Christian',
#  'Virginia Tech',
#  'Albany (NY)',
#  'Sacramento State',
#  'Texas Southern',
#  'American',
#  'Bucknell',
#  'Rutgers',
#  'Texas A&M-Corpus Christi',
#  'Norfolk State',
#  'Marshall',
#  'Bryant',
#  'College of Charleston',
#  'Mississippi State',
#  'Texas-Arlington',
#  'NJIT',
#  'Southeast Missouri State',
#  'Northern Arizona',
#  'Florida A&M',
#  'South Alabama',
#  'Wagner',
#  'Northeastern',
#  "Mount St. Mary's",
#  'Western Illinois',
#  'Hampton',
#  'Cal State Fullerton',
#  'North Carolina-Greensboro',
#  'Samford',
#  'Liberty',
#  'Southern Illinois-Edwardsville',
#  'Arkansas-Pine Bluff',
#  'Campbell',
#  'Holy Cross',
#  'Idaho State',
#  'Loyola (IL)',
#  'Georgia Southern',
#  'Alabama A&M',
#  'Dartmouth',
#  'Brown',
#  'Grand Canyon',
#  'Lipscomb',
#  'Army',
#  'Louisiana-Monroe',
#  'New Orleans',
#  'IUPUI',
#  'North Carolina-Wilmington',
#  'UMKC',
#  'Texas Christian',
#  'Bradley',
#  'Jacksonville',
#  'Coppin State',
#  'McNeese State',
#  'Seattle',
#  'Southeastern Louisiana',
#  'Cal State Bakersfield',
#  'San Jose State',
#  'Longwood',
#  'UC-Davis',
#  'Fairleigh Dickinson',
#  'Alcorn State',
#  'Central Michigan',
#  'Rice',
#  'Morgan State',
#  'Central Arkansas',
#  'South Carolina State',
#  'Colgate',
#  'Delaware State',
#  'Lehigh',
#  'UC-Riverside',
#  'Lafayette',
#  'Austin Peay',
#  'Jackson State',
#  'Central Connecticut',
#  'Fordham',
#  'Eastern Illinois',
#  'Marist',
#  "St. Peter's",
#  'Prairie View',
#  'Savannah State',
#  'Nicholls State',
#  'UIC',
#  'Jacksonville State',
#  'James Madison',
#  'Mississippi Valley State',
#  'Hartford',
#  'Rider',
#  'Ball State',
#  'Loyola (MD)',
#  'UTSA',
#  'Furman',
#  'Texas State',
#  'New Hampshire',
#  'Appalachian State',
#  'UMass-Lowell',
#  'Hofstra',
#  'Niagara',
#  'Howard',
#  'UMBC',
#  'Penn',
#  'Monmouth',
#  'North Carolina A&T',
#  'Kennesaw State',
#  'Maine',
#  'Northern Kentucky',
#  'Fairfield',
#  'Stetson',
#  'LIU-Brooklyn',
#  'Texas-Rio Grande Valley',
#  'Houston Baptist',
#  'Navy',
#  'UT-Martin',
#  'Maryland-Eastern Shore',
#  'Tennessee State',
#  'Bethune-Cookman',
#  'Citadel',
#  'Saint Francis (PA)',
#  'Presbyterian',
#  'Southern Utah',
#  'Binghamton',
#  'Cornell',
#  'Metropolitan State',
#  'Grambling',
#  'Sacred Heart',
#  'Lamar',
#  'Nova Southeastern',
#  'West Alabama',
#  'Texas-Permian Basin',
#  'Wilmington (OH)',
#  'Chowan',
#  'Emporia State',
#  'Mars Hill',
#  'McMurry',
#  'Wilmington (DE)',
#  'Lyon',
#  'Columbus State',
#  'Oakland City',
#  'Hope International',
#  'Hawaii Pacific',
#  'Shenandoah',
#  'Tampa',
#  'Manchester',
#  'Johnson University',
#  'Covenant',
#  'Colorado-Colorado Springs',
#  'North Carolina Wesleyan',
#  'Albion',
#  'Washington & Lee',
#  'Caldwell',
#  'Ave Maria',
#  'Sewanee',
#  'Columbia International',
#  'Washington College',
#  'Ohio Northern',
#  'Randolph',
#  'Greensboro',
#  'Viterbo University',
#  'Northwood (TX)',
#  'LeTourneau',
#  'UC-Santa Cruz',
#  'Martin Methodist',
#  'Notre Dame de Namur',
#  'Bethesda',
#  'Arizona Christian',
#  'Texas-Tyler',
#  'Huston-Tillotson',
#  'Evergreen State',
#  'Wittenberg',
#  'Trinity Baptist',
#  'Earlham (IN)',
#  'Urbana',
#  'Cairn',
#  'Southern Tech',
#  'Northern Michigan',
#  'Louisiana College',
#  'Mid-Continent',
#  'Suffolk',
#  'San Diego Christian',
#  'St. Thomas (TX)',
#  'Loyola (LA)',
#  'Northwestern Ohio',
#  'Roanoke',
#  'Tougaloo',
#  'Tuskegee',
#  'Lyndon State',
#  'Pacific (OR)',
#  'Gwynedd-Mercy',
#  'Fisher College',
#  'St. Andrews',
#  'Haverford',
#  'North Park',
#  'Mount St. Joseph',
#  'UC-Merced',
#  'Holy Names',
#  'Guilford',
#  'Michigan-Dearborn',
#  "Crowley's Ridge",
#  'Indiana-Kokomo',
#  'Warren Wilson',
#  'Eastern',
#  'Morehouse',
#  'Johnson & Wales (NC)',
#  'Coe',
#  'Schreiner',
#  'Hillsdale Baptist/Randall (Ok.)',
#  'Central Baptist',
#  'Wiley',
#  'Trinity (TX)',
#  'LaGrange',
#  'Emory & Henry',
#  'Mississippi College',
#  'Taylor (IN)',
#  'Hendrix',
#  'Iowa Wesleyan',
#  'Concordia (MI)',
#  'MIT',
#  'Ferrum',
#  'Florida College',
#  'Rio Grande',
#  'Salisbury',
#  'Brescia',
#  'Millsaps',
#  'Colorado Christian',
#  'Tennessee Temple',
#  'Chestnut Hill',
#  'Mobile',
#  'Olivet Nazarene',
#  'Roosevelt',
#  'Centenary (LA)',
#  'Reinhardt',
#  'Goucher',
#  'Newberry',
#  'Minnesota-Morris',
#  'Pacific Lutheran',
#  'Howard Payne',
#  'Alabama-Huntsville',
#  'Florida National University',
#  'Champion Baptist',
#  'Simpson (CA)',
#  'Virginia Union',
#  'Rochester (MI)',
#  'Mesa State',
#  'West Virginia Wesleyan',
#  'Montreat',
#  'North Greenville',
#  'Toccoa Falls',
#  'Western New Mexico',
#  'Northwest Nazarene',
#  'Wingate',
#  'Brevard',
#  'Bluefield State',
#  'Pacifica',
#  'Stillman',
#  'Dillard',
#  'Eckerd',
#  'William Carey',
#  'Southwest State (MN)',
#  'Lees-McRae',
#  'Trinity (FL)',
#  'Walla Walla',
#  'Allen',
#  'Indiana-Northwest',
#  'Rockhurst',
#  'Bethel (TN)',
#  'Purdue Calumet',
#  'Jarvis Christian',
#  'Cedarville',
#  'Bridgewater (VA)',
#  'Thiel',
#  'Hawaii-Hilo',
#  'Webber',
#  'Missouri S&T',
#  'Eureka',
#  'Truman State',
#  'Dalton State',
#  'Southwestern (TX)',
#  'Northern New Mexico',
#  'Anderson (IN)',
#  'Minnesota-Duluth',
#  'Heidelberg',
#  'Voorhees',
#  'Virginia Intermont',
#  'Westminster (PA)',
#  "Saint Joseph's (IN)",
#  'Chaminade',
#  'Ohio Valley',
#  'Bob Jones University',
#  'Blue Mountain College',
#  'Southern Arkansas',
#  'Truett-McConnell',
#  'Judson',
#  'Barber-Scotia',
#  'Campbellsville',
#  'Limestone',
#  'Fort Valley State',
#  'Sonoma State',
#  'Mount Saint Vincent',
#  'Alaska-Anchorage',
#  'Salve Regina',
#  'Florida Memorial',
#  'Texas A&M-International',
#  'Graceland (IA)',
#  'Cincinnati Christian',
#  'Greenville (IL)',
#  'Hardin-Simmons',
#  'La Sierra',
#  'Mount Ida College',
#  'Kentucky State',
#  'Baptist Bible (PA)',
#  'Valley City State',
#  'Edward Waters',
#  'Spring Hill',
#  'Black Hills State',
#  'Arkansas-Fort Smith',
#  'Fayetteville State',
#  'Vanguard',
#  'Waldorf',
#  'Cameron',
#  'Dallas Baptist',
#  'Brewton-Parker',
#  'Young Harris',
#  "St. Edward's",
#  'West Virginia Tech',
#  'Catholic',
#  'Central Pennsylvania College',
#  'Dakota State',
#  'Oakwood',
#  'Carroll (MT)',
#  'La Verne',
#  'Wisconsin-Parkside',
#  'St. Katherine',
#  'Grace Bible',
#  'Southwestern Oklahoma State',
#  'Mount Olive',
#  'Western State',
#  'Thomas University',
#  'Fisk',
#  'Virginia-Lynchburg',
#  'Hiwassee',
#  'Colorado College',
#  'Claflin',
#  'Coker',
#  'Bluefield College (VA)',
#  'Cal State Dominguez Hills',
#  'Clearwater Christian',
#  'Menlo',
#  'William Jessup',
#  'St. Catharine',
#  'Philadelphia',
#  "Saint Martin's",
#  'Presentation',
#  'Tusculum',
#  'Open Bible College',
#  'Bacone',
#  'Immaculata',
#  'Alice Lloyd',
#  'Notre Dame (OH)',
#  'San Francisco State',
#  'Wayne State (NE)',
#  'Southwestern Christian',
#  'Montana Western',
#  'Haskell Indian Nations Institute',
#  'Milligan',
#  'Montana State-Billings',
#  'Wayland Baptist',
#  'Westminster (UT)',
#  'Southeastern',
#  'Elmhurst',
#  'Ursinus',
#  'Laroche',
#  'Indiana Tech',
#  'Defiance',
#  'Auburn Montgomery',
#  'St. Francis (IL)',
#  'Belhaven (MS)',
#  'Albertus Magnus',
#  'Robert Morris (IL)',
#  'Coast Guard',
#  'Ecclesia',
#  'Central Methodist',
#  'Asbury',
#  'Houghton',
#  'Lesley',
#  'Selma University',
#  'Warner Southern',
#  'Siena Heights',
#  'Marygrove',
#  "Master's",
#  'Our Lady of the Lake',
#  'Kalamazoo',
#  'Mayville State',
#  'Daniel Webster',
#  'Oberlin',
#  'Baruch College',
#  'CCNY',
#  'LeMoyne-Owen',
#  'Kean',
#  'Peru State',
#  'Wheelock',
#  'Maine-Fort Kent',
#  'Dallas Christian',
#  'Arlington Baptist',
#  'Southwestern Adventist']

# %% [markdown]
# ### NCAA Men's 2014 Rank

# %%
rank_ncaa_teams("ncaa2014.csv")
# Out:
# ['Duke',
#  'Wisconsin',
#  'Notre Dame',
#  'North Carolina State',
#  'Virginia',
#  'Kentucky',
#  'Maryland',
#  'Louisville',
#  'Michigan State',
#  'UNC',
#  'Miami (FL)',
#  'Arizona',
#  'Villanova',
#  'Kansas',
#  'Providence',
#  'Iowa State',
#  'West Virginia',
#  'Baylor',
#  'Xavier',
#  'Oklahoma',
#  'Georgetown',
#  'Pitt',
#  'Utah',
#  'Syracuse',
#  'Rutgers',
#  'Wichita State',
#  'VCU',
#  'Iowa',
#  'Gonzaga',
#  'Northern Iowa',
#  'San Diego State',
#  'Oregon',
#  'Butler',
#  'Ohio State',
#  'Indiana',
#  'Stanford',
#  'Arizona State',
#  'Seton Hall',
#  'Cincinnati',
#  'Purdue',
#  'Illinois',
#  "St. John's (NY)",
#  'Arkansas',
#  'Dayton',
#  'Kansas State',
#  'UCLA',
#  'UNLV',
#  'Oregon State',
#  'BYU',
#  'Wyoming',
#  'Oklahoma State',
#  'Illinois State',
#  'Old Dominion',
#  'SMU',
#  'LSU',
#  'Boise State',
#  'Colorado State',
#  'Temple',
#  'Ole Miss',
#  'Texas',
#  'Valparaiso',
#  'Richmond',
#  'Clemson',
#  'Washington',
#  'George Washington',
#  'Minnesota',
#  'Green Bay',
#  'Alabama-Birmingham',
#  'Davidson',
#  'Evansville',
#  'Michigan',
#  'Georgia',
#  'Georgia State',
#  'Murray State',
#  'South Carolina',
#  'Stephen F. Austin',
#  'Wofford',
#  'UConn',
#  'Auburn',
#  'Texas A&M',
#  'University of California',
#  'Louisiana Tech',
#  'Vanderbilt',
#  'Wake Forest',
#  'Florida',
#  'Alabama',
#  'UTEP',
#  'Tennessee',
#  'New Mexico',
#  'Florida State',
#  'Rhode Island',
#  'Tulsa',
#  'Buffalo',
#  'Nebraska',
#  'Loyola (IL)',
#  'Middle Tennessee',
#  'Boston College',
#  'La Salle',
#  'Louisiana',
#  'Colorado',
#  'Penn State',
#  'UC-Davis',
#  'Central Michigan',
#  'South Dakota State',
#  'UC-Irvine',
#  'Akron',
#  'Hawaii',
#  'Western Kentucky',
#  'Creighton',
#  'Marquette',
#  'Harvard',
#  'Yale',
#  'Kent State',
#  'Washington State',
#  'Gardner-Webb',
#  "Saint Mary's (CA)",
#  'Sam Houston State',
#  'Eastern Washington',
#  'Northwestern',
#  'Utah State',
#  'UMass',
#  'Georgia Tech',
#  'DePaul',
#  'Fresno State',
#  'NJIT',
#  'Cleveland State',
#  'Belmont',
#  'UCSB',
#  'St. Bonaventure',
#  'Georgia Southern',
#  'Louisiana-Monroe',
#  'High Point',
#  'Eastern Kentucky',
#  'Eastern Michigan',
#  'Oakland',
#  'Toledo',
#  'Coastal Carolina',
#  'Pepperdine',
#  'Northern Arizona',
#  'Long Beach State',
#  'Texas Tech',
#  'North Dakota State',
#  'Texas Christian',
#  'Memphis',
#  'Oral Roberts',
#  'Chattanooga',
#  'Iona',
#  'Western Michigan',
#  'North Florida',
#  'Texas A&M-Corpus Christi',
#  'Radford',
#  'New Mexico State',
#  'Florida Gulf Coast',
#  'Albany (NY)',
#  'William & Mary',
#  'Indiana State',
#  'Charleston Southern',
#  'Northeastern',
#  'Stony Brook',
#  'Seattle',
#  'Portland',
#  'Bowling Green State',
#  'Montana',
#  'Lafayette',
#  "St. Joseph's",
#  'Detroit',
#  'Winthrop',
#  'USC',
#  'Holy Cross',
#  'Texas Southern',
#  'Bucknell',
#  'Mississippi State',
#  'Eastern Illinois',
#  'UTSA',
#  'Fort Wayne',
#  'South Carolina Upstate',
#  'Sacramento State',
#  'Brown',
#  'Lehigh',
#  'Missouri',
#  'Florida International',
#  'South Dakota',
#  'American',
#  'Texas-Arlington',
#  'UT-Martin',
#  'Canisius',
#  'Wright State',
#  'Air Force',
#  'San Diego',
#  'Incarnate Word',
#  'Colgate',
#  'Dartmouth',
#  'Idaho',
#  'St. Francis (NY)',
#  'North Texas',
#  'Delaware State',
#  'Vermont',
#  'Duquesne',
#  'New Hampshire',
#  'Saint Francis (PA)',
#  'Quinnipiac',
#  'Milwaukee',
#  'San Francisco',
#  'Miami (OH)',
#  'ETSU',
#  'North Carolina-Asheville',
#  'Northern Illinois',
#  'Tulane',
#  'Princeton',
#  'East Carolina',
#  'Houston',
#  'North Carolina Central',
#  'Robert Morris',
#  'Rice',
#  'Marshall',
#  'Northwestern State',
#  'Texas State',
#  'Cornell',
#  'Houston Baptist',
#  'Western Carolina',
#  'Cal Poly',
#  'James Madison',
#  'Norfolk State',
#  'UC-Riverside',
#  'Rider',
#  "St. Peter's",
#  'Lipscomb',
#  'Boston University',
#  'Mercer',
#  'Grand Canyon',
#  'Portland State',
#  'UMKC',
#  'Jacksonville State',
#  'Youngstown State',
#  'Morehead State',
#  'Manhattan',
#  'Army',
#  'UCF',
#  'Columbia',
#  'North Carolina-Wilmington',
#  'Pacific',
#  'Tennessee Tech',
#  'Northern Kentucky',
#  'Charlotte',
#  'Appalachian State',
#  'Navy',
#  'Sacred Heart',
#  'Troy',
#  'Southern Illinois',
#  'Southern Miss',
#  'Northern Colorado',
#  'Hofstra',
#  'George Mason',
#  'Longwood',
#  'Denver',
#  'Monmouth',
#  'Citadel',
#  'Santa Clara',
#  'Howard',
#  'Virginia Tech',
#  'Nevada',
#  'South Alabama',
#  'Cal State Bakersfield',
#  'Weber State',
#  'Southern Illinois-Edwardsville',
#  'Maryland-Eastern Shore',
#  'Florida Atlantic',
#  'Bradley',
#  'Little Rock',
#  'Ohio',
#  'Bryant',
#  'Elon',
#  'Hartford',
#  'Chicago State',
#  'Texas-Rio Grande Valley',
#  'Lamar',
#  'Austin Peay',
#  'UIC',
#  'Arkansas State',
#  'Southeast Missouri State',
#  'Omaha',
#  'Missouri State',
#  'Jacksonville',
#  'UMass-Lowell',
#  'Saint Louis',
#  'LIU-Brooklyn',
#  'Loyola (MD)',
#  'Samford',
#  'Hampton',
#  'Furman',
#  'North Carolina-Greensboro',
#  "Mount St. Mary's",
#  'McNeese State',
#  'Delaware',
#  'Virginia Military Institute',
#  'Ball State',
#  'Western Illinois',
#  'Cal State Fullerton',
#  'South Florida',
#  'Cal State Northridge',
#  'New Orleans',
#  'Kennesaw State',
#  'Campbell',
#  'Liberty',
#  'IUPUI',
#  'Savannah State',
#  'Drake',
#  'Prairie View',
#  'Idaho State',
#  'North Dakota',
#  'Drexel',
#  'Fordham',
#  'Siena',
#  'Niagara',
#  'Presbyterian',
#  'Abilene Christian',
#  'Alabama State',
#  'Stetson',
#  'Nicholls State',
#  'Southeastern Louisiana',
#  'Southern',
#  'Southern Utah',
#  'Loyola Marymount',
#  'Utah Valley',
#  'Fairleigh Dickinson',
#  'Penn',
#  'Wagner',
#  'Towson',
#  'Montana State',
#  'Bethune-Cookman',
#  'South Carolina State',
#  'College of Charleston',
#  'Marist',
#  'Tennessee State',
#  'Arkansas-Pine Bluff',
#  'North Carolina A&T',
#  'Morgan State',
#  'Coppin State',
#  'Fairfield',
#  'Alabama A&M',
#  'Binghamton',
#  'Grambling',
#  'Jackson State',
#  'Central Connecticut',
#  'Southeastern Oklahoma State',
#  'Alcorn State',
#  'Ferris State',
#  'San Jose State',
#  'Mississippi Valley State',
#  'Maine',
#  'UMBC',
#  'Central Arkansas',
#  'Alaska-Anchorage',
#  'Florida A&M',
#  'University of the Sciences (Pa.)',
#  'Caldwell',
#  'Concordia (AL)',
#  'Hillsdale',
#  'Auburn Montgomery',
#  'Chapman',
#  'Barber-Scotia',
#  'Alma',
#  'Hiwassee',
#  'Trinity Baptist',
#  'Rochester (MI)',
#  'North Carolina Wesleyan',
#  'St. Francis (IL)',
#  'Florida College',
#  'NYIT',
#  'Tennessee Temple',
#  'MIT',
#  'Eastern Oregon',
#  'Texas-Tyler',
#  'Manchester',
#  'Randolph',
#  'Berry',
#  'Averett',
#  'Louisiana College',
#  'Rockhurst',
#  'Piedmont',
#  'Ohio Valley',
#  'Pfeiffer',
#  'Greensboro',
#  'Chowan',
#  'Arkansas-Monticello',
#  'Black Hills State',
#  'Concordia (OR)',
#  'Pace',
#  'Cal State Los Angeles',
#  'Austin College',
#  'Bethesda University (CA)',
#  'Carroll (MT)',
#  'Flagler',
#  'Harris-Stowe',
#  'William Carey',
#  'Mississippi College',
#  'Edward Waters',
#  'Reinhardt',
#  'Our Lady of the Lake',
#  'Wayland Baptist',
#  'Huston-Tillotson',
#  'Brewton-Parker',
#  'Trinity (TX)',
#  'UC-San Diego',
#  'Catholic',
#  'Bluefield State',
#  'Earlham (IN)',
#  'Nova Southeastern',
#  'Illinois-Springfield',
#  'San Francisco State',
#  'Aurora',
#  'San Diego Christian',
#  'Berea',
#  'Holy Names',
#  'Goucher',
#  'Florida National University',
#  'Louisiana State-Alexandria',
#  'Ohio Dominican',
#  'Trevecca Nazarene',
#  'Aquinas',
#  'Oberlin',
#  'Young Harris',
#  'Indiana-Kokomo',
#  'Erskine',
#  'Tiffin',
#  'Baptist Bible (PA)',
#  'Eureka',
#  'Fairleigh Dickinson-Florham',
#  'Warner Southern',
#  'Bristol University',
#  'Champion Baptist',
#  'McKendree',
#  'Minnesota-Crookston',
#  'Cincinnati Christian',
#  'Adams State',
#  'Webber',
#  'Lyon',
#  'Cal Lutheran',
#  'Franklin Pierce',
#  'Presentation College',
#  'Newbury',
#  'Indiana-Northwest',
#  'Columbia International',
#  'Virginia Wise',
#  'Kentucky Christian',
#  'Trinity (CT)',
#  'Malone',
#  'West Virginia Tech',
#  'Thomas (ME)',
#  'Cairn',
#  'College of Faith',
#  'Mayville State',
#  'Northwest Oklahoma State',
#  'Corban',
#  'Willamette',
#  'Hannibal-LaGrange',
#  'Johnson University',
#  'Western State',
#  'Colorado Christian',
#  'Hartwick',
#  'Southern Virginia',
#  'Toccoa Falls',
#  'Walla Walla',
#  'Hawaii-Hilo',
#  'Missouri S&T',
#  'Avila',
#  'Johnson & Wales (NC)',
#  'Simpson',
#  'Notre Dame de Namur',
#  'Indiana-South Bend',
#  'Southern Vermont',
#  'Eckerd',
#  'Virginia-Lynchburg',
#  'Brescia',
#  'Pacific Union',
#  'Keystone',
#  'Bob Jones University',
#  'Palm Beach Atlantic',
#  'Fisk',
#  'Bluefield (WV)',
#  'Florida Memorial',
#  'Jarvis Christian',
#  'Oakwood',
#  "Master's",
#  'Trinity Christian',
#  'Cincinnati-Clermont',
#  'Florida Christian',
#  'St. Thomas Aquinas',
#  'Miles',
#  'Transylvania',
#  'Ohio Mid-Western',
#  'Texas A&M-Kingsville',
#  'Southern-New Orleans',
#  'St. Katherine',
#  'Nichols',
#  'Hood',
#  'Catawba',
#  'Merchant Marine',
#  'Newman',
#  'Dillard',
#  'Chaminade',
#  'Texas A&M-International',
#  'Clayton State',
#  'Chadron State',
#  'Peace',
#  'Saint Xavier (IL)',
#  'Mount Ida',
#  'Penn State-Harrisburg',
#  'Wayne State (NE)',
#  'Emerson',
#  'Warren Wilson',
#  'Brevard',
#  'Dallas Christian',
#  'Gwynedd-Mercy',
#  'Concordia-St. Paul',
#  'William Jewell',
#  'Missouri Valley',
#  'University of the Southwest',
#  'Olivet Nazarene',
#  'Greenville',
#  'Johnson & Wales (RI)',
#  'Ave Maria',
#  'Fort Valley State',
#  'Penn State-Mont Alto',
#  'Langston',
#  'Howard Payne',
#  'Goldey-Beacom',
#  'Marygrove',
#  'Minnesota-Duluth',
#  'Pacific Lutheran',
#  'Montana Western',
#  'St. Andrews',
#  'Spring Hill',
#  'Mid-Atlantic Christian',
#  'Florida Tech',
#  'South Dakota School of Mines',
#  'Bethel (TN)',
#  'Cal State East Bay',
#  'Schreiner',
#  'Texas Lutheran',
#  "St. Edward's",
#  'Middle Georgia State',
#  'Belhaven (MS)',
#  'Menlo',
#  'Vanguard',
#  'Thomas University',
#  'Selma University',
#  'Great Falls',
#  'Wheelock',
#  "Crowley's Ridge",
#  'Loyola (LA)',
#  'Central Pennsylvania College',
#  'Limestone',
#  'Ouachita',
#  'Urbana',
#  'Regis',
#  'Thiel',
#  'Montreat',
#  'Morrisville State',
#  'Mars Hill',
#  'Iowa Wesleyan',
#  'Trinity International (IL)',
#  'Northwest Nazarene',
#  'Michigan-Dearborn',
#  'Tusculum',
#  'Northern New Mexico',
#  'Arkansas-Fort Smith',
#  'Arlington Baptist',
#  'Centenary (LA)',
#  'Mount Saint Vincent',
#  'Mitchell',
#  'Mount Vernon Nazarene',
#  'Northwest University',
#  'Truman State',
#  'Susquehanna',
#  'Central Baptist',
#  'King (TN)',
#  'Ferrum',
#  'Milligan',
#  'Oakland City',
#  'Cal State Dominguez Hills',
#  'St. Thomas (TX)',
#  'Stillman',
#  'Case Western Reserve',
#  'Concordia (MI)',
#  'Dickinson State (ND)',
#  'Washington College',
#  'Wilberforce',
#  'Bluffton',
#  "Saint Joseph's (IN)",
#  'Truett-McConnell',
#  'Penn State-Beaver',
#  'Arkansas Tech',
#  'Coker',
#  'Goshen',
#  'Lewis & Clark',
#  'Coast Guard',
#  'Judson',
#  'Northwest Christian',
#  'Northland',
#  'Haskell Indian Nations Institute',
#  'Robert Morris (IL)',
#  'Wentworth',
#  'Quincy',
#  'Southern Arkansas',
#  'Capital',
#  'Midwestern State',
#  'Alice Lloyd',
#  'Ecclesia',
#  'Cameron',
#  'St. Catharine',
#  'Anderson (SC)',
#  'La Verne',
#  'Hampden-Sydney',
#  'North Alabama',
#  'Cal State Maritime',
#  'Fresno Pacific',
#  'Cheyney',
#  'Saint Rose',
#  'Rhodes',
#  'New Mexico Highlands',
#  'Allen',
#  'Alfred',
#  'Daniel Webster',
#  'Lyndon State',
#  'Montana Tech',
#  "St. Joseph's (NY)",
#  'Albion',
#  'Rowan',
#  'Tabor College',
#  'Baker',
#  'Paine',
#  'Fisher College',
#  'Texas College',
#  'Maine-Fort Kent',
#  'Sarah Lawrence']

# %% [markdown]
# ### NCAA Men's 2015 Rank

# %%
rank_ncaa_teams("ncaa2015.csv")
# Out:
# ['Villanova',
#  'Virginia',
#  'Oklahoma',
#  'Kansas',
#  'UNC',
#  'Oregon',
#  'Xavier',
#  'Seton Hall',
#  'Michigan State',
#  'Miami (FL)',
#  'West Virginia',
#  'Iowa State',
#  'Duke',
#  'Texas',
#  'Wisconsin',
#  'Notre Dame',
#  'Utah',
#  'Syracuse',
#  'Iowa',
#  'Indiana',
#  'Providence',
#  'Texas A&M',
#  'George Washington',
#  'Kentucky',
#  'University of California',
#  'Purdue',
#  'Northern Iowa',
#  'Louisville',
#  'Texas Tech',
#  'Maryland',
#  "St. Joseph's",
#  'Georgia Tech',
#  'Virginia Tech',
#  'Arizona',
#  'Baylor',
#  'Gonzaga',
#  'Colorado',
#  'Oregon State',
#  'Butler',
#  'San Diego State',
#  'Dayton',
#  'Pitt',
#  'Wichita State',
#  'VCU',
#  'Florida State',
#  'UConn',
#  'Michigan',
#  'Valparaiso',
#  'Florida',
#  'BYU',
#  'Creighton',
#  "Saint Mary's (CA)",
#  'Stanford',
#  'SMU',
#  'South Carolina',
#  'Clemson',
#  'Boise State',
#  'St. Bonaventure',
#  'Long Beach State',
#  'USC',
#  'Cincinnati',
#  'Alabama',
#  'Georgia',
#  'Fresno State',
#  'UCLA',
#  'Little Rock',
#  'UNLV',
#  'Vanderbilt',
#  'Georgetown',
#  'Middle Tennessee',
#  'Tulsa',
#  'LSU',
#  'Oklahoma State',
#  'Hawaii',
#  'Temple',
#  'Ohio State',
#  'Davidson',
#  'Marquette',
#  'Kansas State',
#  'South Dakota State',
#  'Arizona State',
#  'Hofstra',
#  'Houston',
#  'Washington',
#  'North Carolina-Wilmington',
#  'Stephen F. Austin',
#  'North Carolina State',
#  'Chattanooga',
#  'Northeastern',
#  'Wright State',
#  'Akron',
#  'New Mexico',
#  'Arkansas',
#  'Tennessee',
#  'Pepperdine',
#  'Louisiana-Monroe',
#  'Green Bay',
#  'Nevada',
#  'Colorado State',
#  'Alabama-Birmingham',
#  'William & Mary',
#  'Nebraska',
#  'Grand Canyon',
#  'Fort Wayne',
#  'Evansville',
#  'Ohio',
#  'UC-Irvine',
#  'Richmond',
#  'Illinois State',
#  'Penn State',
#  'Monmouth',
#  'Western Kentucky',
#  'ETSU',
#  'Illinois',
#  'Morehead State',
#  'James Madison',
#  'Northern Illinois',
#  'Ole Miss',
#  'Coastal Carolina',
#  'Buffalo',
#  'Omaha',
#  'North Dakota State',
#  'Oakland',
#  'Louisiana Tech',
#  'Auburn',
#  'Ball State',
#  'Duquesne',
#  'Belmont',
#  'Central Michigan',
#  'Memphis',
#  'New Mexico State',
#  'Eastern Michigan',
#  'Old Dominion',
#  'Stony Brook',
#  'Indiana State',
#  'Kent State',
#  'Northwestern',
#  'Southern Illinois',
#  'North Carolina-Asheville',
#  'Weber State',
#  'Winthrop',
#  'Towson',
#  'Rhode Island',
#  'High Point',
#  'IUPUI',
#  'Loyola (IL)',
#  'Yale',
#  'Furman',
#  'Milwaukee',
#  'Texas-Arlington',
#  'Wake Forest',
#  'Wyoming',
#  'Georgia State',
#  'Mississippi State',
#  'Toledo',
#  'College of Charleston',
#  'Oral Roberts',
#  'Miami (OH)',
#  'Idaho',
#  'Utah State',
#  'UCSB',
#  'Air Force',
#  'Siena',
#  'Cal State Bakersfield',
#  'George Mason',
#  'Radford',
#  'UT-Martin',
#  'Arkansas State',
#  'Princeton',
#  'Florida Gulf Coast',
#  'Albany (NY)',
#  'Montana',
#  'North Carolina-Greensboro',
#  'Texas Christian',
#  'North Florida',
#  'Western Carolina',
#  'Columbia',
#  'La Salle',
#  'Marshall',
#  'DePaul',
#  'Louisiana',
#  'Bowling Green State',
#  'UMass',
#  'Vermont',
#  'UC-Riverside',
#  'Iona',
#  'Murray State',
#  'Missouri State',
#  'Detroit',
#  'Texas A&M-Corpus Christi',
#  'Denver',
#  'Harvard',
#  'Tennessee Tech',
#  'Western Michigan',
#  'Gardner-Webb',
#  'Liberty',
#  'South Dakota',
#  'UTEP',
#  'North Dakota',
#  'Saint Louis',
#  'Fordham',
#  'UMKC',
#  'Elon',
#  'Wagner',
#  'Western Illinois',
#  'Minnesota',
#  'Austin Peay',
#  'NJIT',
#  'Portland',
#  'Tennessee State',
#  'Tulane',
#  'Navy',
#  'Eastern Washington',
#  'Army',
#  'San Jose State',
#  'Appalachian State',
#  'Longwood',
#  'Missouri',
#  'Southern',
#  'South Alabama',
#  'Mercer',
#  'Seattle',
#  'Wofford',
#  'Georgia Southern',
#  'Houston Baptist',
#  'Incarnate Word',
#  'East Carolina',
#  'Sacramento State',
#  'Boston University',
#  'New Hampshire',
#  'Fairleigh Dickinson',
#  'Eastern Kentucky',
#  'Cal Poly',
#  'Bucknell',
#  'Stetson',
#  'Idaho State',
#  'Texas State',
#  'Sam Houston State',
#  'Eastern Illinois',
#  'Youngstown State',
#  'Jacksonville',
#  'Rice',
#  'Fairfield',
#  'Hampton',
#  'Samford',
#  'Washington State',
#  'Lipscomb',
#  'Cal State Fullerton',
#  'Lehigh',
#  'Colgate',
#  'Northern Colorado',
#  'Florida International',
#  'Montana State',
#  'Charleston Southern',
#  'South Florida',
#  'Norfolk State',
#  'Holy Cross',
#  'Charlotte',
#  'Canisius',
#  'Campbell',
#  'San Francisco',
#  'Cleveland State',
#  'Pacific',
#  'Portland State',
#  'South Carolina State',
#  'San Diego',
#  'North Texas',
#  'Manhattan',
#  'Northern Kentucky',
#  'Cal State Northridge',
#  'Savannah State',
#  'South Carolina Upstate',
#  'Alabama State',
#  'Virginia Military Institute',
#  "St. John's (NY)",
#  'Southern Miss',
#  'Abilene Christian',
#  'Loyola Marymount',
#  'Jackson State',
#  'Bethune-Cookman',
#  'Citadel',
#  'Lamar',
#  'LIU-Brooklyn',
#  'Troy',
#  'Howard',
#  'Presbyterian',
#  'St. Francis (NY)',
#  'Nicholls State',
#  'American',
#  'Texas-Rio Grande Valley',
#  'Utah Valley',
#  'Kennesaw State',
#  'New Orleans',
#  "St. Peter's",
#  'Cornell',
#  'Saint Francis (PA)',
#  'UC-Davis',
#  'McNeese State',
#  'Texas Southern',
#  'Santa Clara',
#  'Drake',
#  'UCF',
#  'UMass-Lowell',
#  'Southeastern Louisiana',
#  'Bradley',
#  'Dartmouth',
#  'UIC',
#  "Mount St. Mary's",
#  'Penn',
#  'Drexel',
#  'Hartford',
#  'Florida Atlantic',
#  'Rider',
#  'Southern Utah',
#  'Jacksonville State',
#  'Alcorn State',
#  'North Carolina Central',
#  'Coppin State',
#  'Northwestern State',
#  'Sacred Heart',
#  'Grambling',
#  'Southern Illinois-Edwardsville',
#  'Bryant',
#  'Alabama A&M',
#  'Chicago State',
#  'Northern Arizona',
#  'Florida A&M',
#  'Delaware State',
#  'Rutgers',
#  'Robert Morris',
#  'UTSA',
#  'Loyola (MD)',
#  'North Carolina A&T',
#  'Maryland-Eastern Shore',
#  'Marist',
#  'Maine',
#  'Boston College',
#  'Morgan State',
#  'Quinnipiac',
#  'Brown',
#  'Southeast Missouri State',
#  'Delaware',
#  'Prairie View',
#  'Lafayette',
#  'Arkansas-Pine Bluff',
#  'Binghamton',
#  'Central Arkansas',
#  'UMBC',
#  'Mississippi Valley State',
#  'Niagara',
#  'Central Connecticut',
#  'Our Lady of the Lake',
#  'Wiley',
#  'William Carey',
#  'Bob Jones University',
#  'Louisiana College',
#  'Louisiana State-Alexandria',
#  'Alaska-Anchorage',
#  'Warner Southern',
#  'Roanoke',
#  'Texas-Permian Basin',
#  'University of the Southwest',
#  'Ferrum',
#  'Trinity (FL)',
#  'Shenandoah',
#  'Pittsburgh-Bradford',
#  'UC-San Diego',
#  'Montreat',
#  'Illinois Tech',
#  'Kean',
#  'Simpson',
#  'Seton Hill',
#  'Johnson University',
#  'Trinity Baptist',
#  'Webber',
#  'Middle Georgia State',
#  'MIT',
#  'Great Falls',
#  'Texas Lutheran',
#  'Austin College',
#  'Covenant',
#  'Randolph',
#  'McMurry',
#  'Millsaps',
#  'Allen',
#  'Northern Michigan',
#  'Cincinnati Christian',
#  'Harris-Stowe',
#  'Lyndon State',
#  'Milligan',
#  'Minnesota-Morris',
#  'Jarvis Christian',
#  'Oregon Tech',
#  'Rutgers-Newark',
#  'San Francisco State',
#  'Florida National University',
#  'Auburn Montgomery',
#  'Chadron State',
#  'Bristol University',
#  'Central Baptist',
#  'San Diego Christian',
#  'William Jessup',
#  'Averett',
#  'Summit',
#  'Brigham Young-Hawaii',
#  'Eureka',
#  'Mid-Atlantic Christian',
#  'Hawaii-Hilo',
#  'Greensboro',
#  'Northwest Christian',
#  'Merchant Marine Academy',
#  'Piedmont',
#  'Loyola (LA)',
#  'West Virginia Tech',
#  'Campbellsville',
#  'George Fox',
#  'North Carolina Wesleyan',
#  'Fort Valley State',
#  'William Jewell',
#  "Saint Mary's (MN)",
#  'Reinhardt',
#  'Hannibal-LaGrange',
#  'Hiram',
#  'Lyon',
#  'Hiwassee',
#  'Central State (OH)',
#  'Fairleigh Dickinson-Florham',
#  'Texas Wesleyan',
#  'Florida Memorial',
#  'Molloy',
#  "Crowley's Ridge",
#  'Dickinson State (ND)',
#  'Schreiner',
#  'Manchester',
#  'Oakwood',
#  'La Roche',
#  'New Mexico Highlands',
#  'Texas College',
#  'Pacific Lutheran',
#  'Voorhees',
#  'Texas-Tyler',
#  'Howard Payne',
#  'Alma',
#  'Malone',
#  'Marian',
#  'Queens (NY)',
#  'Black Hills State',
#  'Oakland City',
#  'Kenyon',
#  'Washington Adventist',
#  'Chowan',
#  'Wentworth',
#  'Colorado Christian',
#  'Tiffin',
#  "Saint Joseph's (IN)",
#  'Westminster',
#  'St. Thomas (TX)',
#  'Mount Saint Vincent',
#  'Adams State',
#  'Tusculum',
#  'Truett-McConnell',
#  'Centenary (LA)',
#  'Emerson',
#  'Cal State Monterey Bay',
#  'Vanguard',
#  'Fresno Pacific',
#  'Johnson & Wales (NC)',
#  'Indiana-Northwest',
#  'Grace Bible',
#  'Goldey-Beacom',
#  'Belmont Abbey',
#  'Thomas University',
#  'Mars Hill',
#  'Valley City State',
#  'Edward Waters',
#  'Toccoa Falls',
#  'Catawba',
#  'Mississippi College',
#  'Fisk',
#  'Indiana-Kokomo',
#  'Emmanuel',
#  'Pensacola Christian',
#  'Mobile',
#  'Trinity Christian',
#  'Antelope Valley',
#  'Siena Heights',
#  'Medgar Evers',
#  'Florida College',
#  'Trinity International (IL)',
#  'Embry-Riddle Aeronautical University',
#  'Holy Names',
#  'Texas A&M-Kingsville',
#  'Union (TN)',
#  'SUNY-Oneonta',
#  'Linfield',
#  'Kentucky State',
#  'Central Pennsylvania College',
#  'Carroll',
#  'Emporia State',
#  'Minnesota-Duluth',
#  'Goucher',
#  'Louisiana State-Shreveport',
#  'Concordia (OR)',
#  'Chaminade',
#  'Chestnut Hill',
#  'Penn State-Harrisburg',
#  'Michigan-Dearborn',
#  'Notre Dame (CA)',
#  "St. Edward's",
#  'Rochester (MI)',
#  'Roosevelt',
#  'East Mennonite',
#  'Wheelock',
#  'South Dakota School of Mines',
#  'Dillard',
#  'Cal State Los Angeles',
#  'Mt. St. Joseph',
#  'Thomas More',
#  'Marygrove',
#  'Lincoln',
#  'Dubuque',
#  'Tabor College',
#  'Gallaudet',
#  'Thiel',
#  'Quincy',
#  'William Woods',
#  'Denison',
#  'Madonna',
#  'Multnomah',
#  'Rowan',
#  'Farmingdale State',
#  'Cincinnati-Clermont',
#  'Staten Island',
#  'Urbana',
#  'Ave Maria',
#  'Maine-Fort Kent',
#  'Selma University',
#  'Spring Hill',
#  'Paul Quinn',
#  'Cal State Dominguez Hills',
#  'Waldorf',
#  'Pacific Union',
#  'Albion',
#  'Willamette',
#  'Fort Lewis',
#  'Mercy',
#  'Coker',
#  'Bethesda University (CA)',
#  'Wayne State (NE)',
#  'Silver Lake',
#  "Master's",
#  'Dallas Christian',
#  'La Verne',
#  'Warren Wilson',
#  'Kentucky Christian',
#  'Sul Ross State',
#  'Angelo State',
#  'Aquinas',
#  'Biola',
#  'Tennessee Wesleyan',
#  'Worcester State',
#  'Henderson State',
#  'Arkansas-Fort Smith',
#  'York (NE)',
#  'John Brown',
#  'Utica',
#  'Cumberland',
#  'North Greenville',
#  'Arkansas-Monticello',
#  'Hawaii Pacific',
#  'Arlington Baptist',
#  'Blue Mountain College',
#  'Tampa',
#  'Williams Baptist',
#  'Coastal Georgia',
#  'Arkansas Tech',
#  'Wesley',
#  'Virginia Wise',
#  'Judson',
#  'Ecclesia',
#  'Columbia International',
#  "Saint Martin's",
#  'Le Tourneau',
#  'Ouachita',
#  'Ohio Dominican',
#  'Geneva',
#  'Hardin-Simmons',
#  'Bluefield College (VA)',
#  'Illinois-Springfield',
#  'Albany State (GA)',
#  'East Central',
#  'Maryville (MO)',
#  'Paine',
#  'Northwest Indian College',
#  'Chapman',
#  'New Hope Christian',
#  'Mary Washington',
#  'Menlo',
#  'Rockhurst',
#  'Missouri Valley',
#  'Ursinus',
#  'Fisher College',
#  'Life Pacific',
#  'Wisconsin-Superior',
#  'Rio Grande',
#  'Johnson & Wales',
#  'Widener',
#  'Purdue Calumet',
#  'Montana Western',
#  'Methodist',
#  'Cairn',
#  'College of Idaho',
#  'Brescia',
#  'Western State',
#  'St. Andrews',
#  'Cedarville',
#  'Regis',
#  'Western Oregon',
#  'Miles',
#  'Southeastern Oklahoma State',
#  'Hillsdale',
#  'Westminster (MO)',
#  'Trevecca Nazarene',
#  'Arizona Christian',
#  'Northland',
#  'Francis Marion',
#  'Lees-McRae',
#  'Florida Tech',
#  'Bridgewater (VA)',
#  'Lourdes',
#  'Cal State East Bay',
#  'Point Loma Nazarene',
#  'Eckerd',
#  'Purdue North Central',
#  'Oberlin',
#  'Boyce',
#  'Daniel Webster',
#  'Ryerson',
#  'Pine Manor',
#  'Bryn Athyn',
#  'Cheyney',
#  'St. Ambrose',
#  'Northern New Mexico',
#  'Benedictine',
#  'Bowie State',
#  'St. Catharine']

# %% [markdown]
# ### NCAA Men's 2016 Rank

# %%
rank_ncaa_teams("ncaa2016.csv")
# Out:
# ['Georgetown',
#  'Illinois',
#  'Xavier',
#  'DePaul',
#  "St. John's (NY)",
#  'Creighton',
#  'Maryland',
#  'Portland',
#  'Louisville',
#  'Pittsburgh',
#  'Marquette',
#  'UCLA',
#  'Florida St.',
#  'Providence',
#  'Villanova',
#  'Seton Hall',
#  'Arizona',
#  'Northwestern',
#  'Minnesota',
#  'Butler',
#  'Syracuse',
#  'Ohio St.',
#  'Notre Dame',
#  'Michigan St.',
#  'Stanford',
#  'Iowa',
#  'Purdue',
#  'North Carolina',
#  'Colorado',
#  'Wisconsin',
#  'Michigan',
#  'Nebraska',
#  'Duke',
#  'Southern California',
#  'Arizona St.',
#  'Oregon',
#  'Virginia',
#  'Tennessee',
#  'UNLV',
#  'Georgia Tech',
#  'Washington',
#  'Oklahoma',
#  'Kentucky',
#  'Indiana',
#  'Miami (FL)',
#  'Kansas',
#  'Texas',
#  'Wake Forest',
#  'Boston College',
#  'California',
#  'Washington St.',
#  'Utah',
#  'Penn St.',
#  'Iowa St.',
#  'Oregon St.',
#  'Ole Miss',
#  'TCU',
#  'Texas Tech',
#  'Clemson',
#  'UNI',
#  'Baylor',
#  'BYU',
#  'Utah St.',
#  'NC State',
#  'Pacific',
#  'Georgia',
#  'South Carolina',
#  'West Virginia',
#  'San Francisco',
#  'Kansas St.',
#  'Missouri',
#  'Virginia Tech',
#  'Loyola Marymount',
#  'Rutgers',
#  'San Diego St.',
#  'Oklahoma St.',
#  'Illinois St.',
#  'Evansville',
#  'San Diego',
#  'Gonzaga',
#  'Colorado St.',
#  'Mississippi St.',
#  'Santa Clara',
#  "Saint Mary's (CA)",
#  'Nevada',
#  'Memphis',
#  'Air Force',
#  'Texas A&M',
#  'Dayton',
#  'Vanderbilt',
#  'Wichita St.',
#  'Southern Ill.',
#  'Indiana St.',
#  'UConn',
#  'Pepperdine',
#  'Hawaii',
#  'Cincinnati',
#  'New Mexico',
#  'Boise St.',
#  'Wyoming',
#  'Auburn',
#  'Arkansas',
#  'Drake',
#  'VCU',
#  'SMU',
#  "Saint Joseph's",
#  'Loyola Chicago',
#  'Alabama',
#  'San Jose St.',
#  'Massachusetts',
#  'Fresno St.',
#  'Bradley',
#  'Richmond',
#  'Saint Louis',
#  'Grand Canyon',
#  'Fordham',
#  'Florida',
#  'Akron',
#  'Tulsa',
#  'Old Dominion',
#  'UCF',
#  'George Washington',
#  'Missouri St.',
#  'La Salle',
#  'South Fla.',
#  'Rhode Island',
#  'George Mason',
#  'Middle Tenn.',
#  'North Texas',
#  'Duquesne',
#  'Houston',
#  'LSU',
#  'Central Mich.',
#  'Valparaiso',
#  'Miami (OH)',
#  'Davidson',
#  'Northern Ill.',
#  'Tulane',
#  'Southern Miss.',
#  'UTEP',
#  'Ball St.',
#  'UMKC',
#  'Charlotte',
#  'St. Bonaventure',
#  'Rice',
#  'Fla. Atlantic',
#  'Temple',
#  'UTSA',
#  'CSUN',
#  'Oakland',
#  'Marshall',
#  'Eastern Mich.',
#  'Buffalo',
#  'Montana',
#  'Louisiana Tech',
#  'Toledo',
#  'Utah Valley',
#  'Western Mich.',
#  'Cal St. Fullerton',
#  'East Carolina',
#  'Bowling Green',
#  'Western Ky.',
#  'Seattle U',
#  'FIU',
#  'New Mexico St.',
#  'Kent St.',
#  'Col. of Charleston',
#  'UTRGV',
#  'Vermont',
#  'Ill.-Chicago',
#  'ETSU',
#  'UC Irvine',
#  'Sacramento St.',
#  'Long Beach St.',
#  'Eastern Wash.',
#  'Youngstown St.',
#  'Coastal Caro.',
#  'Montana St.',
#  'Ohio',
#  'Western Caro.',
#  'UAB',
#  'Cal Poly',
#  'Brown',
#  'Boston U.',
#  'Weber St.',
#  'Portland St.',
#  'UC Riverside',
#  'Elon',
#  'High Point',
#  'UC Davis',
#  'UC Santa Barbara',
#  'Mercer',
#  'CSU Bakersfield',
#  'Green Bay',
#  'Chattanooga',
#  'FGCU',
#  'Idaho',
#  'Harvard',
#  'Princeton',
#  'South Dakota',
#  'Drexel',
#  'Murray St.',
#  'UNCG',
#  'Army West Point',
#  'Delaware',
#  'Navy',
#  'Belmont',
#  'Lafayette',
#  'UNCW',
#  'Georgia St.',
#  'Southeast Mo. St.',
#  'SFA',
#  'Cleveland St.',
#  'Bucknell',
#  'New Hampshire',
#  'Winthrop',
#  'Louisiana',
#  'Penn',
#  'UT Martin',
#  'Northern Ariz.',
#  'Samford',
#  'Wright St.',
#  'North Florida',
#  'Southern Utah',
#  'Austin Peay',
#  'South Ala.',
#  'SIUE',
#  'Lehigh',
#  'Colgate',
#  'Tennessee Tech',
#  'Lamar University',
#  'Liberty',
#  'UNC Asheville',
#  'Northern Colo.',
#  'Milwaukee',
#  'Detroit Mercy',
#  'Yale',
#  'The Citadel',
#  'Columbia',
#  'Binghamton',
#  'Northern Ky.',
#  'William & Mary',
#  'Stony Brook',
#  'Chicago St.',
#  'UT Arlington',
#  'Sam Houston St.',
#  'Hofstra',
#  'American',
#  'Furman',
#  'Houston Baptist',
#  'Fort Wayne',
#  'New Orleans',
#  'La.-Monroe',
#  'Arkansas St.',
#  'McNeese',
#  'Campbell',
#  'Towson',
#  'Albany (NY)',
#  'Holy Cross',
#  'Maine',
#  'Texas St.',
#  'Morehead St.',
#  'Appalachian St.',
#  'Eastern Ill.',
#  'Radford',
#  'Jacksonville St.',
#  'Nicholls St.',
#  'Little Rock',
#  'James Madison',
#  'Idaho St.',
#  'Lipscomb',
#  'North Dakota',
#  'Ga. Southern',
#  'Wofford',
#  'VMI',
#  'Troy',
#  'Loyola Maryland',
#  'Incarnate Word',
#  'UMBC',
#  'Cornell',
#  'Iona',
#  'Charleston So.',
#  'Presbyterian',
#  'Abilene Christian',
#  'Longwood',
#  'Tennessee St.',
#  'Eastern Ky.',
#  'UMass Lowell',
#  'Robert Morris',
#  'Jacksonville',
#  'Oral Roberts',
#  'Saint Francis (PA)',
#  'Northeastern',
#  'Omaha',
#  'Dartmouth',
#  'Hartford',
#  'Gardner-Webb',
#  'Bryant',
#  'Kennesaw St.',
#  'Wagner',
#  'IUPUI',
#  'Southeastern La.',
#  'NJIT',
#  'USC Upstate',
#  'South Dakota St.',
#  'St. Francis Brooklyn',
#  'North Dakota St.',
#  'Denver',
#  'Canisius',
#  'Stetson',
#  'Siena',
#  'Sacred Heart',
#  'Southern U.',
#  "Mt. St. Mary's",
#  'Monmouth',
#  'LIU Brooklyn',
#  'Morgan St.',
#  'Central Ark.',
#  'Northwestern St.',
#  'Manhattan',
#  'Quinnipiac',
#  'Western Ill.',
#  'Rider',
#  'Central Conn. St.',
#  'Grambling',
#  'Florida A&M',
#  "Saint Peter's",
#  'Jackson St.',
#  'Fairfield',
#  'N.C. Central',
#  'Alabama St.',
#  'Alcorn',
#  'Bethune-Cookman',
#  'Savannah St.',
#  'Marist',
#  'Fairleigh Dickinson',
#  'Niagara',
#  'Prairie View',
#  'Chaminade',
#  'Coppin St.',
#  'N.C. A&T',
#  'Howard',
#  'A&M-Corpus Christi',
#  'Hampton',
#  'Delaware St.',
#  'Ark.-Pine Bluff',
#  'Alabama A&M',
#  'Norfolk St.',
#  'A&M-Corpus Chris',
#  'UMES',
#  'Mississippi Val.',
#  'Texas Southern',
#  'South Carolina St.',
#  'Alas. Anchorage',
#  'Northern N.M.',
#  'Anderson (SC)',
#  'Benedictine Mesa',
#  'Ave Maria',
#  'Point U.',
#  'Warren Wilson',
#  'Nazareth',
#  'Marygrove',
#  'Johnson (FL)',
#  'Fisher',
#  'Okla. Panhandle',
#  'Fontbonne',
#  'Mississippi Col.',
#  'LIFE Pacific',
#  'George Fox',
#  'Antelope Valley',
#  'Middle Ga. St.',
#  'Doane',
#  'Wilmington (DE)',
#  'Selma',
#  'Trinity (FL)',
#  'Dallas Christian',
#  'Hiram',
#  'Lewis & Clark',
#  'Goshen',
#  'Northeastern St.',
#  'Union (TN)',
#  'Bethesda (CA)',
#  'Chatham',
#  'Trinity Baptist',
#  'Trinity Christian',
#  'Mo.-St. Louis',
#  'Lyndon St.',
#  'Edward Waters',
#  'Southern-N.O.',
#  'Presentation',
#  'Blue Mountain',
#  'Fort Valley St.',
#  'Xavier (LA)',
#  'St. Francis (IL)',
#  'Western New Eng.',
#  'East-West U.',
#  'Toccoa Falls',
#  'Hawaii Hilo',
#  'Ecclesia',
#  'Dalton St.',
#  'Waldorf',
#  'Fla. National',
#  'LSU-Alexandria',
#  'Jarvis Christian',
#  'Westminster (PA)',
#  'Madonna',
#  'Okla. Baptist',
#  'Hiwassee',
#  'Medaille',
#  'Florida Col.',
#  'Rowan',
#  'Ark.-Monticello',
#  'Me.-Presque Isle',
#  'Spalding',
#  'Reinhardt',
#  'Bryn Athyn',
#  'Howard Payne',
#  'Ferris St.',
#  'Allen',
#  'Chestnut Hill',
#  'Siena Heights',
#  'Arizona Christian',
#  'Southern Ore.',
#  'Ind.-Kokomo',
#  'Central Penn',
#  'Paul Quinn',
#  'Brevard',
#  'Union (NY)',
#  'Adrian',
#  'Mansfield',
#  'Pacific Union',
#  'Methodist',
#  'Menlo',
#  'Texas Col.',
#  'Rogers St.',
#  'Western Ore.',
#  'Wabash',
#  'Lees-McRae',
#  'LSU-Shreveport',
#  'Johnson & Wales (NC)',
#  'Northwest (WA)',
#  'Sonoma St.',
#  'Messiah',
#  'Centenary (LA)',
#  'UC Merced',
#  'Oberlin',
#  "Crowley's Ridge",
#  'Boyce',
#  "Piedmont Int'l",
#  'Tougaloo',
#  'Texas-Dallas',
#  'Providence (MT)',
#  'Greensboro',
#  'Loyola (LA)',
#  'Mt. St. Vincent',
#  'Emerson',
#  'Pomona-Pitzer',
#  'Keystone',
#  'Ga. Southwestern',
#  'Johnson & Wales (RI)',
#  'Austin',
#  'Miles',
#  'Missouri Western',
#  'John Brown',
#  'Cal St. East Bay',
#  'Southeastern Okla.',
#  "Tex. A&M Int'l",
#  'William Jewell',
#  'West Coast Baptist',
#  'Montreat',
#  'Ferrum',
#  'Manhattanville',
#  'Thomas (GA)',
#  'Bethel (TN)',
#  'New Hope Christian',
#  'Randall',
#  'Averett',
#  'Tenn. Wesleyan',
#  'Holy Names',
#  'Olivet Nazarene',
#  'Southern Wesleyan',
#  'Clarks Summit',
#  'N.C. Wesleyan',
#  'Montana Tech',
#  'Milligan',
#  'Arlington Baptist',
#  'Northwest Nazarene',
#  'Coastal Ga.',
#  'William Jessup',
#  'Kean',
#  'Mobile',
#  'Lake Erie',
#  'Fla. Memorial',
#  "Master's",
#  'Moravian',
#  'West Va. Wesleyan',
#  'Daniel Webster',
#  "Webber Int'l",
#  'Williams Baptist',
#  'Brescia',
#  'St. Thomas Houston',
#  'Wayland Baptist',
#  'Cabrini',
#  'Dean',
#  'Fisk',
#  "Saint Mary's (MN)",
#  'Roosevelt',
#  'Mt. St. Joseph',
#  'Walla Walla',
#  'Rust',
#  'Staten Island',
#  'Grace (IN)',
#  'Lander',
#  'Marian (IN)',
#  'Mars Hill',
#  'Asbury',
#  'Truett-McConnell',
#  'Huston-Tillotson',
#  'Missouri S&T',
#  'Olivet',
#  'Henderson St.',
#  'Our Lady of the Lake',
#  'East Central',
#  'Marywood',
#  'Ohio Christian',
#  'Florida Tech',
#  'Ill.-Springfield',
#  'North Georgia',
#  'Palm Beach Atl.',
#  'Wheelock',
#  'Mitchell',
#  'McGill (CAN)',
#  'San Diego Christian',
#  'Ottawa (KS)',
#  'Trevecca Nazarene']

# %% [markdown]
# ### NCAA Men's 2017 Rank

# %%
rank_ncaa_teams("ncaa2017.csv")
# Out:
# ['Villanova',
#  'Kansas',
#  'Providence',
#  'West Virginia',
#  'Michigan',
#  'Texas Tech',
#  'Virginia',
#  'UNC',
#  'Xavier',
#  'Butler',
#  'Florida',
#  'Duke',
#  'Kentucky',
#  'Tennessee',
#  'Purdue',
#  'Texas A&M',
#  'Creighton',
#  'Alabama',
#  'Oklahoma State',
#  'Florida State',
#  'Virginia Tech',
#  'Arizona',
#  'Clemson',
#  'Auburn',
#  "St. John's (NY)",
#  'Oklahoma',
#  'Loyola (IL)',
#  'Kansas State',
#  'Arkansas',
#  'Nevada',
#  'Arizona State',
#  'Seton Hall',
#  'Cincinnati',
#  'Houston',
#  'Ohio State',
#  'Texas Christian',
#  'Gonzaga',
#  'Wichita State',
#  'Missouri',
#  'Baylor',
#  'Syracuse',
#  'Washington',
#  'LSU',
#  'North Carolina State',
#  'Texas',
#  'Utah',
#  'Georgia',
#  'Western Kentucky',
#  'Mississippi State',
#  'Michigan State',
#  'Penn State',
#  'USC',
#  'Marquette',
#  'UCLA',
#  'Oregon',
#  'San Diego State',
#  'Miami (FL)',
#  'UMBC',
#  'Colorado',
#  'Louisville',
#  'Stanford',
#  "Saint Mary's (CA)",
#  'South Carolina',
#  'Rhode Island',
#  'Notre Dame',
#  'Temple',
#  'St. Bonaventure',
#  'Middle Tennessee',
#  'Boise State',
#  'Wyoming',
#  'Buffalo',
#  'Marshall',
#  'Nebraska',
#  'Boston College',
#  'Iowa State',
#  'Missouri State',
#  'SMU',
#  'Bradley',
#  'South Dakota State',
#  'San Francisco',
#  'North Carolina-Greensboro',
#  'Davidson',
#  'New Mexico State',
#  'BYU',
#  'Vanderbilt',
#  'Oregon State',
#  'Maryland',
#  'Illinois State',
#  'Ole Miss',
#  'Wisconsin',
#  'Fresno State',
#  'Vermont',
#  'UNLV',
#  'College of Charleston',
#  'Northern Colorado',
#  'Belmont',
#  'Indiana State',
#  'Southern Illinois',
#  'Northern Iowa',
#  'South Dakota',
#  'Memphis',
#  'Murray State',
#  'Northwestern',
#  'New Mexico',
#  'Northeastern',
#  'Utah Valley',
#  'Eastern Michigan',
#  'Utah State',
#  'UCF',
#  'Stephen F. Austin',
#  'Montana',
#  'Towson',
#  'Wofford',
#  'Drake',
#  'Saint Louis',
#  'Milwaukee',
#  'Old Dominion',
#  'Minnesota',
#  'ETSU',
#  'Georgetown',
#  'Toledo',
#  'Georgia State',
#  'Washington State',
#  'Tulsa',
#  'North Texas',
#  'William & Mary',
#  'Wright State',
#  'Seattle',
#  'Louisiana',
#  'UCSB',
#  'Jacksonville State',
#  'Drexel',
#  'San Diego',
#  'UTSA',
#  'Idaho',
#  'Texas-Arlington',
#  'Alabama-Birmingham',
#  'Radford',
#  'UC-Davis',
#  'Georgia Tech',
#  'North Carolina-Asheville',
#  'Lipscomb',
#  'Evansville',
#  'Ball State',
#  'Indiana',
#  'Portland State',
#  'Hawaii',
#  'UC-Irvine',
#  'Eastern Washington',
#  'Kent State',
#  "St. Joseph's",
#  'Illinois',
#  'Furman',
#  'Central Michigan',
#  'Miami (OH)',
#  'Dayton',
#  'Hofstra',
#  'Liberty',
#  'Cal State Fullerton',
#  'Valparaiso',
#  'Tulane',
#  'Northern Kentucky',
#  'Southeastern Louisiana',
#  'Bucknell',
#  'DePaul',
#  'Elon',
#  'Florida Gulf Coast',
#  'Long Beach State',
#  'Albany (NY)',
#  'Weber State',
#  'UMass',
#  'Wake Forest',
#  'Bowling Green State',
#  'Fort Wayne',
#  'Western Michigan',
#  'Rider',
#  'Georgia Southern',
#  'Lamar',
#  'Sam Houston State',
#  'Ohio',
#  'VCU',
#  'Rutgers',
#  'Grand Canyon',
#  'Penn',
#  'Oakland',
#  'North Dakota State',
#  'Wagner',
#  'Winthrop',
#  'Mercer',
#  'Denver',
#  'Troy',
#  'Hartford',
#  'UConn',
#  'Southern Miss',
#  'Northern Illinois',
#  'Colgate',
#  'Iowa',
#  'Tennessee Tech',
#  'Central Arkansas',
#  'Louisiana-Monroe',
#  'Campbell',
#  'Louisiana Tech',
#  'Austin Peay',
#  'Nicholls State',
#  'UIC',
#  'Western Illinois',
#  'University of California',
#  'Cal State Bakersfield',
#  'Stony Brook',
#  'Richmond',
#  'Harvard',
#  'Iona',
#  'Oral Roberts',
#  'Niagara',
#  'LIU-Brooklyn',
#  'Tennessee State',
#  'Citadel',
#  'George Mason',
#  'La Salle',
#  'Princeton',
#  'Canisius',
#  'Charleston Southern',
#  'George Washington',
#  "Mount St. Mary's",
#  'High Point',
#  'Texas-Rio Grande Valley',
#  'Abilene Christian',
#  'North Carolina-Wilmington',
#  'Akron',
#  'Boston University',
#  'Colorado State',
#  'Appalachian State',
#  'Gardner-Webb',
#  'Southeast Missouri State',
#  'IUPUI',
#  'Pacific',
#  'New Orleans',
#  'Coastal Carolina',
#  'Florida International',
#  'Hampton',
#  'Duquesne',
#  'Saint Francis (PA)',
#  'Montana State',
#  'NJIT',
#  'Army',
#  'Lehigh',
#  'Southern Utah',
#  'South Alabama',
#  'North Carolina Central',
#  'Omaha',
#  'McNeese State',
#  'North Carolina A&T',
#  'Delaware',
#  'Cal Poly',
#  'Green Bay',
#  'Fairleigh Dickinson',
#  'UC-Riverside',
#  'Texas State',
#  'Yale',
#  'Binghamton',
#  'Fairfield',
#  'Loyola Marymount',
#  'Navy',
#  'Idaho State',
#  'UMKC',
#  'North Florida',
#  'St. Francis (NY)',
#  'Jacksonville',
#  'Arkansas State',
#  'Portland',
#  'Air Force',
#  'Robert Morris',
#  'Monmouth',
#  'James Madison',
#  'Cleveland State',
#  'Morehead State',
#  'Florida Atlantic',
#  'Presbyterian',
#  'Grambling',
#  'Texas A&M-Corpus Christi',
#  'Eastern Illinois',
#  'New Hampshire',
#  'Chattanooga',
#  'North Dakota',
#  'Morgan State',
#  'Manhattan',
#  'Little Rock',
#  'Santa Clara',
#  'UTEP',
#  'Eastern Kentucky',
#  'Pitt',
#  'Bethune-Cookman',
#  'UT-Martin',
#  'South Carolina Upstate',
#  'Western Carolina',
#  'Youngstown State',
#  "St. Peter's",
#  'South Florida',
#  'Incarnate Word',
#  'Sacramento State',
#  'UMass-Lowell',
#  'Loyola (MD)',
#  'Longwood',
#  'South Carolina State',
#  'Cornell',
#  'Stetson',
#  'Brown',
#  'Savannah State',
#  'East Carolina',
#  'Prairie View',
#  'Central Connecticut',
#  'Lafayette',
#  'Holy Cross',
#  'Samford',
#  'Southern',
#  'Houston Baptist',
#  'Kennesaw State',
#  'Maine',
#  'Columbia',
#  'Norfolk State',
#  'Virginia Military Institute',
#  'Southern Illinois-Edwardsville',
#  'Sacred Heart',
#  'Florida A&M',
#  'Quinnipiac',
#  'Howard',
#  'Fordham',
#  'Siena',
#  'Detroit',
#  'Alcorn State',
#  'Delaware State',
#  'Chicago State',
#  'Dartmouth',
#  'Texas Southern',
#  'Jackson State',
#  'Charlotte',
#  'Maryland-Eastern Shore',
#  'Northwestern State',
#  'Arkansas-Pine Bluff',
#  'Cal State Northridge',
#  'Rice',
#  'Marist',
#  'Pepperdine',
#  'San Jose State',
#  'American',
#  'Northern Arizona',
#  'Bryant',
#  'Alabama State',
#  'Coppin State',
#  'Mississippi Valley State',
#  'Concordia-St. Paul',
#  'Alabama A&M',
#  'Southern Nazarene',
#  'Chaminade',
#  'William Jewell',
#  'Alaska-Anchorage',
#  'Lynchburg',
#  'Elizabeth City State',
#  'Ouachita',
#  'LeTourneau',
#  'Louisiana State-Shreveport',
#  'Embry-Riddle Aeronautical University',
#  'Spring Arbor',
#  'Trevecca Nazarene',
#  'Webber',
#  'Millsaps',
#  'Wheelock',
#  'Oglethorpe',
#  'Siena Heights',
#  'Walla Walla',
#  'Bridgewater (VA)',
#  'Eureka',
#  'Methodist',
#  'Piedmont',
#  'Cairn',
#  'Florida Memorial',
#  'Bob Jones University',
#  'Carver Bible',
#  'MIT',
#  'Clarks Summit',
#  'Emory',
#  'Texas-Tyler',
#  'Georgia Southwestern',
#  'CCNY',
#  'Missouri Baptist University',
#  'Hillsdale',
#  'Johnson University',
#  'UC-Santa Cruz',
#  'Southwestern',
#  'Tennessee Wesleyan',
#  'Valley Forge',
#  'Wisconsin-La Crosse',
#  'Brescia',
#  'Greensboro',
#  'Avila',
#  'Centenary (LA)',
#  'Southern-New Orleans',
#  'Midway',
#  'Our Lady of the Lake',
#  'North Park',
#  'Whitworth',
#  'East Central',
#  'Louisiana College',
#  'Eastern Oregon',
#  'Whittier',
#  'Life Pacific',
#  'San Diego Christian',
#  'Antelope Valley',
#  'La Verne',
#  'Toccoa Falls',
#  'Johnson & Wales (RI)',
#  'Coe',
#  'Peace',
#  'North Carolina Wesleyan',
#  'Mayville State',
#  "Saint Mary's (MN)",
#  'Northern New Mexico',
#  'Massachusetts-Boston',
#  'Wilmington (OH)',
#  'Michigan-Dearborn',
#  'Washington & Lee',
#  'Allen',
#  'Mary',
#  'Gordon',
#  'Defiance',
#  'Wentworth',
#  'University of the Ozarks',
#  'Bluefield College (VA)',
#  'Haskell Indian Nations Institute',
#  'Puget Sound',
#  'Columbia International',
#  'Arcadia',
#  'Anderson (SC)',
#  'Lees-McRae',
#  'Frostburg State',
#  'Trinity (TX)',
#  'Ecclesia',
#  'Rockhurst',
#  'Mobile',
#  'Reinhardt',
#  'Trinity Christian',
#  'George Fox',
#  'John Jay',
#  'Emerson',
#  'Hardin-Simmons',
#  'Ohio Northern',
#  'Franciscan',
#  'Silver Lake',
#  'Arlington Baptist',
#  'West Coast Baptist',
#  'Chapman',
#  'San Francisco State',
#  'Cal Lutheran',
#  'Notre Dame (CA)',
#  'Willamette',
#  'Middle Georgia State',
#  'Fairleigh Dickinson-Florham',
#  'New Rochelle',
#  'Hiwassee',
#  'Oakland City',
#  'Wartburg',
#  "St. Edward's",
#  'Kentucky Wesleyan',
#  'Holy Names',
#  'Montana Western',
#  'Edward Waters',
#  'Johnson & Wales',
#  'Kentucky State',
#  'Bluefield State',
#  'Ohio Christian',
#  'Central Pennsylvania College',
#  'Lincoln (PA)',
#  'Boyce',
#  'Howard Payne',
#  'LeMoyne-Owen',
#  'Jarvis Christian',
#  'St. Francis (IL)',
#  'Brewton-Parker',
#  'Wesley',
#  'McMurry',
#  'Warren Wilson',
#  'Ferrum',
#  'Lakeland',
#  'Spring Hill',
#  'Penn St. - Brandywine',
#  'Kean',
#  'Bethesda University (CA)',
#  'Illinois-Springfield',
#  'Calvary',
#  'Eastern',
#  'Curry',
#  'Oregon Tech',
#  'Molloy',
#  'SUNY-Oneonta',
#  'Lake Erie',
#  'Johnson & Wales (NC)',
#  'Albany State (GA)',
#  'Paine',
#  'Ave Maria',
#  'Tiffin',
#  'Emporia State',
#  'Mount Marty',
#  'Blue Mountain College',
#  'Mars Hill',
#  'Brevard',
#  'Trinity Baptist',
#  'Goucher',
#  'Goldey-Beacom',
#  'York (PA)',
#  'Mid-Atlantic Christian',
#  'Ohio Valley',
#  'Staten Island',
#  'Shenandoah',
#  'Westminster',
#  'East-West',
#  'Northland',
#  'Sonoma State',
#  'Benedictine',
#  'Mitchell',
#  'St. Andrews',
#  'Washington College',
#  'Bethel (TN)',
#  'Champion Baptist',
#  'Missouri-St. Louis',
#  'Augustana (IL)',
#  'Maine-Fort Kent',
#  'Missouri S&T',
#  'Rogers State',
#  'Quincy',
#  'Western New Mexico',
#  'Fontbonne',
#  'Evangel',
#  'Northwood (MI)',
#  'Florida College',
#  'Georgian Court',
#  'Asbury',
#  'Concordia (AL)',
#  'St. Thomas (TX)',
#  'Black Hills State',
#  'Hartwick',
#  'Dakota State',
#  'Mississippi College',
#  'Wheaton (MA)',
#  'Concord',
#  'Rockford',
#  'Rust',
#  'New Mexico Highlands',
#  'Carroll',
#  "St. Mary's (MD)",
#  'Saint Leo',
#  'Texas-Dallas',
#  'Adams State',
#  'Schreiner',
#  'Morris College',
#  'Hannibal-LaGrange',
#  'Dallas Christian',
#  'Harris-Stowe',
#  'Presentation College',
#  'Loyola (LA)',
#  'Fisk',
#  'Cal State Los Angeles',
#  'Florida National University',
#  'Berea',
#  'Lyon',
#  'Wiley',
#  'Shawnee State',
#  'Alice Lloyd',
#  'Indiana-Kokomo',
#  'Christendom',
#  'Ottawa',
#  'Multnomah',
#  'Texas Lutheran',
#  'Fayetteville State',
#  'Williams Baptist',
#  'Portland Bible College',
#  'Miles',
#  'Arkansas-Fort Smith',
#  'Western State',
#  'Tougaloo',
#  'Pacific Lutheran',
#  'Maine-Presque Isle',
#  'Wisconsin-Parkside',
#  'Concorida (NE)',
#  'Central State (OH)',
#  'Indianapolis',
#  'Erskine',
#  'William Jessup',
#  'North Georgia',
#  'Henderson State',
#  'Northwest Nazarene',
#  'Hawaii-Hilo',
#  'North Greenville',
#  'Maine-Machias',
#  'Milligan',
#  'Cincinnati-Clermont',
#  'Mercy',
#  'Dubuque',
#  'Panhandle State',
#  'Kentucky Christian',
#  'Point',
#  'Catholic',
#  'Valley City State',
#  'Eastern New Mexico',
#  "Saint Martin's",
#  'Washington Adventist',
#  'Montreat',
#  'Southern Wesleyan',
#  'Barclay',
#  'Thomas University',
#  "St. Mary's (TX)",
#  'Simon Fraser University',
#  'Lyndon State',
#  'Linfield',
#  'SUNY-Maritime',
#  'William Carey',
#  'Culver-Stockton',
#  'Bethany College (KS)',
#  'Rio Grande',
#  'Cornell (IA)',
#  'Coastal Georgia',
#  'Susquehanna',
#  'Bethany (WV)',
#  'Cal State Monterey Bay',
#  'Lewis',
#  'Texas College',
#  'Great Falls',
#  'Montana Tech',
#  'Southeastern',
#  'Pittsburgh-Bradford',
#  'Bryn Athyn',
#  'UC-Merced',
#  'Limestone',
#  'Lourdes',
#  'Tusculum',
#  'Olivet',
#  'Colorado Mesa',
#  'Rochester (MI)',
#  'Lawrence',
#  'Northwestern Ohio',
#  'Jamestown',
#  'Elmira',
#  'Concordia (MI)',
#  'Texas A&M-International',
#  'Pacific Union',
#  'Florida Tech',
#  'Centenary (NJ)',
#  'Lincoln Christian',
#  'Doane College',
#  'Sarah Lawrence',
#  'Oak Hills',
#  'East Texas Baptist',
#  'Nebraska Christian',
#  'Rowan',
#  'Wayland Baptist',
#  'Peru State',
#  'Bemidji State']

# %% [markdown]
# ### NCAA Men's 2018 Rank

# %%
rank_ncaa_teams("ncaa2018.csv")
# Out:
# ['Duke',
#  'North Carolina',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Virginia',
#  'Mich. St.',
#  'Florida State',
#  'LSU',
#  'Iowa State',
#  'Michigan',
#  'Houston',
#  'Kansas St.',
#  'Texas Tech',
#  'Texas',
#  'Marquette',
#  'UCF',
#  'Gonzaga',
#  'Villanova',
#  'Seton Hall',
#  'Louisville',
#  'Auburn',
#  'Purdue',
#  'Temple',
#  'Virginia Tech',
#  'Syracuse',
#  'Wisconsin',
#  'Baylor',
#  'Indiana',
#  'Mississippi St.',
#  'Oklahoma',
#  "St. John's",
#  'West Virginia',
#  'Iowa',
#  'Maryland',
#  'Arizona St.',
#  'Alabama',
#  'Florida',
#  'Cincinnati',
#  'Buffalo',
#  'TCU',
#  "St. Mary's (Cal.)",
#  'Minnesota',
#  'Utah State',
#  'Georgetown',
#  'Penn St.',
#  'Nevada',
#  'Xavier',
#  'Memphis',
#  'San Diego State',
#  'Creighton',
#  'Oklahoma State',
#  'Bowling Green',
#  'Ohio St.',
#  'Oregon',
#  'Nebraska',
#  'Mississippi',
#  'Butler',
#  'VCU',
#  'Providence',
#  'Arkansas',
#  'Wichita State',
#  'Old Dominion',
#  'Wofford',
#  'Northern Ill.',
#  'Washington',
#  'Illinois',
#  'Toledo',
#  'Clemson',
#  'Western Ky.',
#  'Penn',
#  'DePaul',
#  'Tulsa',
#  'Northeastern',
#  'Florida Atlantic',
#  'Davidson',
#  'Boston College',
#  'NC State',
#  'Drake',
#  'South Carolina',
#  'Belmont',
#  'Pittsburgh',
#  'Harvard',
#  'New Mexico St.',
#  'Colorado',
#  'Murray State',
#  'BYU',
#  'Furman',
#  'Vermont',
#  'Arizona',
#  'Lipscomb',
#  'Fresno State',
#  'Rhode Island',
#  'Charleston',
#  'Texas A&M',
#  'Louisiana Tech',
#  'UC Irvine',
#  'Jacksonville St.',
#  'UNCG',
#  'Saint Louis',
#  'Marshall',
#  'Northern Kentucky',
#  'UAB',
#  'Liberty',
#  'Oregon St.',
#  'Radford',
#  'Rutgers',
#  'Hofstra',
#  'Georgia State',
#  'Missouri',
#  'Central Mich.',
#  'UNI',
#  'San Diego',
#  'Montana',
#  'Kent State',
#  'Southern Miss',
#  'UMBC',
#  'FIU',
#  'Wright State',
#  'Eastern Mich.',
#  'Bradley',
#  'Utah Valley',
#  'San Francisco',
#  'Sam Houston St.',
#  'Ga. Southern',
#  'Dayton',
#  'Illinois State',
#  'Yale',
#  'Loyola Chicago',
#  'UCLA',
#  'New Mexico',
#  'Abilene Christian',
#  'Brown',
#  'Utah',
#  'Pepperdine',
#  'Bucknell',
#  'Texas State',
#  'Akron',
#  'USC',
#  'Notre Dame',
#  'North Texas',
#  'UTSA',
#  'Colgate',
#  'Ball State',
#  'Stony Brook',
#  'James Madison',
#  'IUPUI',
#  "Saint Joseph's",
#  'Georgia Tech',
#  'Missouri State',
#  'East Tenn. St.',
#  'Indiana State',
#  'Southern Ill.',
#  'Ohio',
#  'Austin Peay',
#  'South Florida',
#  'Princeton',
#  'Miami (Ohio)',
#  'Stanford',
#  'Green Bay',
#  'Northwestern',
#  'Louisiana',
#  'UT Arlington',
#  'Grand Canyon',
#  'South Dakota St.',
#  'UIC',
#  'Northern Colo.',
#  'Miami (Fla.)',
#  'Campbell',
#  'Cornell',
#  'Duquesne',
#  'Texas Southern',
#  'LMU',
#  'Omaha',
#  'Gardner-Webb',
#  'UTRGV',
#  'NJIT',
#  'UConn',
#  'Coastal Caro.',
#  'La.-Monroe',
#  'SMU',
#  'Fort Wayne',
#  'Portland State',
#  'SFA',
#  'Southeastern La.',
#  'New Orleans',
#  'Georgia',
#  "Fairleigh D'son",
#  'Central Ark.',
#  'CSU Bakersfield',
#  'Evansville',
#  'Oakland',
#  'North Florida',
#  'Hartford',
#  'Delaware',
#  'Cal Baptist',
#  'Weber State',
#  'Seattle U',
#  'North Dakota St.',
#  'St. Bonaventure',
#  'Pacific',
#  'Boston U.',
#  'Eastern Wash.',
#  'Hawaii',
#  'Long Beach St.',
#  'UC Santa Barb.',
#  'Charleston So.',
#  'Winthrop',
#  'Cleveland State',
#  'Columbia',
#  'South Alabama',
#  'William & Mary',
#  'St. Francis (Pa.)',
#  'Samford',
#  'Lamar University',
#  'Massachusetts',
#  'Holy Cross',
#  'Lehigh',
#  'Wake Forest',
#  'Vanderbilt',
#  'High Point',
#  'East Carolina',
#  'George Mason',
#  'Valparaiso',
#  'UNLV',
#  'Troy',
#  'Santa Clara',
#  'Colorado State',
#  'Rice',
#  'Longwood',
#  'Youngstown St.',
#  'Air Force',
#  'Arkansas State',
#  'Mass.-Lowell',
#  'Washington St.',
#  'Texas A&M-C.C.',
#  'FGCU',
#  'Southern Utah',
#  'Eastern Kentucky',
#  'Robert Morris',
#  'Drexel',
#  'Detroit Mercy',
#  'Hampton',
#  'Eastern Illinois',
#  "St. Francis (B'klyn)",
#  'American',
#  'Fordham',
#  'North Dakota',
#  'Dartmouth',
#  'Presbyterian',
#  'Montana St.',
#  'California',
#  'Boise State',
#  'Middle Tenn.',
#  'South Dakota',
#  'Albany',
#  'Army West Point',
#  'Sacramento St.',
#  'CSU Fullerton',
#  'Sacred Heart',
#  'Charlotte',
#  'Prairie View A&M',
#  'Western Illinois',
#  'Siena',
#  'Towson',
#  'UNCW',
#  'LIU Brooklyn',
#  'Navy',
#  'Richmond',
#  'Binghamton',
#  'Norfolk State',
#  'UMKC',
#  'Grambling',
#  'Oral Roberts',
#  'Little Rock',
#  'La Salle',
#  'Howard',
#  "Mt. St. Mary's",
#  'Nicholls State',
#  'Citadel',
#  'Iona',
#  'Niagara',
#  'Loyola (Md.)',
#  'CSUN',
#  'Monmouth',
#  'UT Martin',
#  'Houston Baptist',
#  'UC Riverside',
#  'Appalachian St.',
#  'Canisius',
#  'Rider',
#  'UC Davis',
#  'Idaho State',
#  'Bethune-Cookman',
#  'Cent. Conn. St.',
#  'Western Mich.',
#  'Wagner',
#  'SIUE',
#  'Lafayette',
#  'Northern Ariz.',
#  'Wyoming',
#  'Mercer',
#  'Florida A&M',
#  'N.C. A&T',
#  'Incarnate Word',
#  'Quinnipiac',
#  "N'western St.",
#  'Elon',
#  'Southeast Mo. St.',
#  'Portland',
#  'S.C. Upstate',
#  'N.C. Central',
#  'Jacksonville',
#  'Morehead State',
#  'VMI',
#  'Marist',
#  'Milwaukee',
#  'UTEP',
#  'New Hampshire',
#  'Ark.-Pine Bluff',
#  'Alcorn State',
#  'Chattanooga',
#  'Geo. Washington',
#  'Bryant',
#  'Chicago State',
#  'Manhattan',
#  'Denver',
#  'Kennesaw State',
#  'Tulane',
#  'Alabama State',
#  'McNeese',
#  'Southern Univ.',
#  'Fairfield',
#  'Morgan State',
#  'Tennessee Tech',
#  'S. Carolina St.',
#  "St. Peter's",
#  'Jackson State',
#  'Tennessee State',
#  'Cal Poly',
#  'Delaware State',
#  'Stetson',
#  'North Alabama',
#  'Savannah State',
#  'UNC Asheville',
#  'Western Caro.',
#  'Idaho',
#  'UMES',
#  'San Jose State',
#  'Mississippi Val.',
#  'Coppin State',
#  'Maine',
#  'William Carey',
#  'Alabama A&M',
#  "St. Edward's",
#  'Lincoln (Pa.)',
#  'Loyola (La.)',
#  'Fayetteville St.',
#  "N'west Nazarene",
#  'Rochester (Mich.)',
#  'Ky. Christian',
#  'Newbury',
#  'Mid-Atlantic Christ.',
#  'Rivier',
#  'Tiffin',
#  'MIT',
#  'Cedarville',
#  'Bob Jones',
#  'Arlington Baptist',
#  'Lenoir-Rhyne',
#  'John. & Wales (Colo.)',
#  'Concordia (Mich.)',
#  'Brevard',
#  'Randolph',
#  'Davis & Elkins',
#  'Mars Hill',
#  'East. Mennonite',
#  'Washington (Md.)',
#  'CCNY',
#  'Wilmington (Ohio)',
#  'Texas Wesleyan',
#  'Ferrum',
#  'E. Texas Bapt.',
#  'Lees-McRae',
#  "Columbia Int'l",
#  'Bemidji State',
#  'Northland',
#  'Fort Valley St.',
#  'Texas A&M-Comm.',
#  'Huston-Tillotson',
#  'Mississippi Coll.',
#  'Angelo State',
#  'UT Tyler',
#  'Saint Leo',
#  'Oakland City',
#  'Rockford',
#  'Sewanee',
#  'Cumberland',
#  'West Coast Baptist',
#  'Spring Hill',
#  'UT Permian Basin',
#  'Centenary (La.)',
#  'Westmin. (Utah)',
#  'Multnomah Bible',
#  'Alaska-Anch.',
#  'Wilberforce',
#  'Fla. Christian',
#  'Florida Tech',
#  'Carver Bible',
#  'Wash. Advent.',
#  'Medgar Evers',
#  "Webber Int'l",
#  'Oglethorpe',
#  'York (NE)',
#  'Howard Payne',
#  'Wis.-Parkside',
#  'Colo. Christian',
#  'CSU Dom. Hills',
#  'Menlo',
#  'LIFE Pacific',
#  'St. Andrews',
#  'Earlham',
#  'Maine-Fort Kent',
#  'Hiwassee',
#  "S'eastern Okla.",
#  "S'western (Texas)",
#  'Hendrix',
#  'Buena Vista',
#  'Puget Sound',
#  'Milligan',
#  'Antelope Valley',
#  'Piedmont',
#  'Our Lady Of The Lake',
#  'St. Francis (Ill.)',
#  'Blue Mountain',
#  'Jarvis Christian',
#  'Bethesda Christian',
#  'Colorado Col.',
#  'Simpson (CA)',
#  'Humboldt State',
#  'Shenandoah',
#  'Tuskegee',
#  'Millsaps',
#  'North Park',
#  'Clarion',
#  'Goucher',
#  'Emerson',
#  'Goshen',
#  'Central Penn',
#  'Middle Ga. St.',
#  'Wesley',
#  'Huntingdon',
#  'Wabash',
#  'LaGrange',
#  'Presentation',
#  'Mt. St. Vincent',
#  'Bridgewater',
#  'Heidelberg',
#  'Misericordia',
#  'Quincy',
#  'Western New Eng.',
#  'Texas Lutheran',
#  'Ozarks',
#  'Pensacola Christian',
#  'Montana Tech',
#  'Sonoma State',
#  'Hardin-Simmons',
#  'Chestnut Hill',
#  'Elms',
#  'Urbana',
#  'Pfeiffer',
#  'Manchester',
#  'Trinity Baptist',
#  'Harding',
#  'Trevecca Nazarene',
#  'Cal Lutheran',
#  'CSU Stanislaus',
#  'Nazareth',
#  'Bryn Athyn',
#  'Lyndon State',
#  'Edward Waters',
#  'McKendree',
#  'Kean',
#  'Queens (N.Y.)',
#  'Mount Aloysius',
#  'Miles',
#  'Dominican (Ill.)',
#  'Boyce',
#  'North Greenville',
#  'Kentucky Wesleyan',
#  'San Diego Christian',
#  'John. & Wales (N.C.)',
#  'NYIT',
#  'Spalding',
#  'Aquinas',
#  'Illinois Tech',
#  'Minnesota-Morris',
#  'California Merced',
#  'Fisk',
#  'Willamette',
#  'Warren Wilson',
#  'Allen',
#  'Wilmington (Del.)',
#  'West Alabama',
#  'Defiance',
#  'SUNY Oneonta',
#  'Ecclesia',
#  'Eastern N.M.',
#  'Lewis & Clark',
#  'Methodist',
#  'Tougaloo',
#  'Mobile',
#  'Concordia (Neb.)',
#  'Champion Bapt.',
#  'Salve Regina',
#  'Molloy',
#  'Southern Wesleyan',
#  'Palm Beach Atl.',
#  'Florida Mem.',
#  'Westmin. (Pa.)',
#  'SUNY Maritime',
#  "St. Mary's (Texas)",
#  'Mass.-Boston',
#  'Ave Maria',
#  'Stockton',
#  'Avila',
#  'Lindenwood',
#  'Siena Heights',
#  'St. Jos. (Brkln.)',
#  'Pine Manor',
#  'Glenville State',
#  'Louisiana Coll.',
#  'Bloomsburg',
#  'Greensboro',
#  'Wiley',
#  'Brewton Parker',
#  'Missouri S&T',
#  'Benedictine Mesa',
#  'Rust',
#  'Western State',
#  'Northwest (Wash.)',
#  'East-West U.',
#  'Montana-Western',
#  'Hartwick',
#  'Albion',
#  'Reinhardt',
#  'Cairn',
#  'Col. of Idaho',
#  'Trinity (Texas)',
#  'Fontbonne',
#  'Le Moyne',
#  'Cal St. San Marcos',
#  'Indiana-Kokomo',
#  'Voorhees',
#  'Trinity Christian',
#  'Frostburg State',
#  'Hawaii-Hilo',
#  'Schreiner',
#  'Central State',
#  'Truman',
#  'Dubuque',
#  'Harris-Stowe',
#  'Central Wash.',
#  'Conc. (Texas)',
#  'Notre Dame (Ohio)',
#  'Georgia College',
#  'Holy Names',
#  'Indiana-Northwest',
#  'Averett',
#  "N'western Ohio",
#  'Mayville State',
#  'Wilson',
#  'Brescia',
#  'Findlay',
#  'Peace',
#  'William Jessup',
#  'N.C. Wesleyan',
#  'Covenant',
#  'Franciscan',
#  'Williams Baptist',
#  'Truett-McConnell',
#  'Florida Col.',
#  'Rosemont',
#  'Coe',
#  'Hood',
#  'Corban',
#  "St. Mary's (Md.)",
#  'Eastern Oregon',
#  'Dallas',
#  'McMurry',
#  'Ark.-Monticello',
#  "S'west Minn. St.",
#  'Coker',
#  'Dixie State',
#  'Bethel (Tenn.)',
#  'La Verne',
#  'Ind.-South Bend',
#  'Carnegie Mellon',
#  'University of the Southwest',
#  'Lyon',
#  "Piedmont Int'l",
#  'William Woods',
#  'Centenary (N.J.)',
#  'Oberlin',
#  'Fla. National',
#  'John. & Wales (R.I.)',
#  'Dickinson State',
#  'Skidmore',
#  'Elmira',
#  'UC Santa Cruz',
#  'Wayland Baptist',
#  "Texas A&M-Int'l"]

# %% [markdown]
# # Special Thanks

# %% [markdown]
# A very special thanks to the Brigham Young University ACME program for their guidance on this project. For further details, please visit https://acme.byu.edu/00000179-afb2-d74f-a3ff-bfbb15980000/pagerank19-pdf
